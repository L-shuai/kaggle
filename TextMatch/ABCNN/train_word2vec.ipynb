# %%
#训练word2Vec
import os
import re

import numpy as np
import pandas as pd
import argparse
from gensim.models import word2vec

# 导入日志模块 创建更漂亮的输出消息
import logging

from hanziconv import HanziConv

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',level=logging.INFO)


def load_training_data(filepath):
    #global x,y
    # 把training时需要的data打开
    # 如果是'training_labe|l.txt'，需要获取label，如果是'training_nolabel.txt'，不需要获取label
    df = pd.read_csv(filepath,sep = "\t")
    df.columns = ['sentence1','sentence2','label']
    #display(df.head())
    x1 = df['sentence1'].apply(lambda x: list(x.strip()))
    x2 = df['sentence2'].apply(lambda x: list(x.strip()))
    x1 = list(x1)
    x2 = list(x2)
    y = df["label"]  #二维的list
    y = list(y)   #一维的list
    print(x1[:100])
    return x1,x2, y


def load_testing_data(path='dataset/testData.tsv'):   #约55万
    # 把testing時需要的data讀進來
    df = pd.read_csv("../data/LCQMC_test.csv",sep = "\t",error_bad_lines=False)
    df.columns = ['sentence1','sentence2']
    x1 = df['sentence1'].apply(lambda x: list(x.strip()))
    x2 = df['sentence2'].apply(lambda x: list(x.strip()))
    x1 = list(x1)
    x2 = list(x2)
    return x1,x2

''' 把句子按字分开，中文按字分，英文数字按空格, 大写转小写，繁体转简体'''
def get_word_list(query):
    query = HanziConv.toSimplified(query.strip())
    regEx = re.compile('[\\W]+')#我们可以使用正则表达式来切分句子，切分的规则是除单词，数字外的任意字符串
    res = re.compile(r'([\u4e00-\u9fa5])')#[\u4e00-\u9fa5]中文范围
    sentences = regEx.split(query.lower())
    str_list = []
    for sentence in sentences:
        if res.split(sentence) == None:
            str_list.append(sentence)
        else:
            ret = res.split(sentence)
            str_list.extend(ret)
    return [w for w in str_list if len(w.strip()) > 0]

# path_prefix = "../model/"
def train_word2vec(x):
  # 训练word embedding
  """
  Embedding 层的输入是一个二维整数张量， 形状为（samples，sequence_length），即（样本数，序列长度）
  Embedding 层输出是（samples，sequence_length，embedding_dimensionality） 的三维浮点数张量。
  较短的序列应该用 0 填充，较长的序列应该被截断，保证输入的序列长度是相同的
  """
  model = word2vec.Word2Vec(x,vector_size=300,window=5,min_count=5,workers=1,epochs=10,sg=1) #iter is epochs
  return model

l = os.listdir()
if "w2v_all.model" not in l:  #如果模型还未创建
  print("加载训练数据")
  train_x1,train_x2,train_y = load_training_data("../data/LCQMC_train.csv")
  dev_x1,dev_x2,dev_y = load_training_data("../data/LCQMC_dev.csv")

  print("加载测试数据集")
  test_x1,test_x2 = load_testing_data("../data/LCQMC_test.csv")
  #训练word embedding时可以将带标签和不代标签的都输入进去   因为这个越多越好   与标签无关
  model = train_word2vec(train_x1+train_x2+dev_x1+dev_x2+test_x1+test_x2)
  print("保存模型")
  model.save("models/w2v_all300.model")
# Out:
# 加载训练数据
# 2022-01-19 22:32:10,292 : INFO : collecting all words and their counts
# 2022-01-19 22:32:10,292 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-19 22:32:10,303 : INFO : PROGRESS: at sentence #10000, processed 107311 words, keeping 2875 word types
# 2022-01-19 22:32:10,315 : INFO : PROGRESS: at sentence #20000, processed 213005 words, keeping 3293 word types
# 2022-01-19 22:32:10,327 : INFO : PROGRESS: at sentence #30000, processed 319467 words, keeping 3570 word types
# 2022-01-19 22:32:10,339 : INFO : PROGRESS: at sentence #40000, processed 425997 words, keeping 3749 word types
# [['我', '手', '机', '丢', '了', '，', '我', '想', '换', '个', '手', '机'], ['大', '家', '觉', '得', '她', '好', '看', '吗'], ['求', '秋', '色', '之', '空', '漫', '画', '全', '集'], ['晚', '上', '睡', '觉', '带', '着', '耳', '机', '听', '音', '乐', '有', '什', '么', '害', '处', '吗', '？'], ['学', '日', '语', '软', '件', '手', '机', '上', '的'], ['打', '印', '机', '和', '电', '脑', '怎', '样', '连', '接', '，', '该', '如', '何', '设', '置'], ['侠', '盗', '飞', '车', '罪', '恶', '都', '市', '怎', '样', '改', '车'], ['什', '么', '花', '一', '年', '四', '季', '都', '开'], ['看', '图', '猜', '一', '电', '影', '名'], ['这', '上', '面', '写', '的', '是', '什', '么', '？'], ['建', '议', '您', '重', '新', '注', '册', '，', '辛', '苦', '您', '了', '。'], ['小', '草', '有', '什', '么', '的', '特', '点', ',', '可', '以', '象', '征', '什', '么', '?'], ['校', '验', '失', '败', '了', '，'], ['尼', '玛', '什', '么', '意', '思'], ['自', '找', '苦', '吃', '的', '地', '方', '是', '哪', '儿', '？'], ['尾', '号', '4', '位', '多', '少'], ['谢', '文', '东', '能', '在', '哪', '里', '看'], ['新', '概', '念', '英', '语', '第', '二', '册', '练', '习', '册', '4', '1', '课', '答', '案'], ['过', '年', '送', '礼', '送', '什', '么', '好'], ['壮', '丁', '是', '什', '么', '生', '肖'], ['这', '是', '什', '么', '蔬', '菜', '啊'], ['最', '近', '有', '什', '么', '好', '电', '视', '剧', '看', '？'], ['性', '与', '爱', '有', '什', '么', '区', '别', '？'], ['网', '上', '卖', '的', '烟', '有', '真', '的', '吗', '？'], ['什', '么', '印', '象'], ['面', '相', '上', '看', '，', '耳', '垂', '上', '有', '痣', '代', '表', '什', '么', '？'], ['男', '生', '喜', '欢', '女', '生', '送', '他', '什', '么', '礼', '物', '呢'], ['如', '何', '快', '速', '忘', '记', '一', '个', '人'], ['周', '杰', '伦', '女', '友', '是', '谁'], ['月', '初', '和', '月', '末', '是', '会', '出', '现', '这', '个', '延', '迟', '的', '情', '况', '的', '，', '小', '二', '建', '议', '您', '耐', '心', '等', '待', '一', '下'], ['支', '付', '宝', '手', '机', '支', '付', '密', '码', '是', '什', '么'], ['关', '于', '网', '页', '设', '计', '的', '问', '题'], ['有', '没', '有', '专', '门', '为', '房', '地', '产', '行', '业', '做', '咨', '询', '的', '公', '司', '啊', '？'], ['这', '系', '列', '的', '漫', '画', '叫', '什', '么', '名', '字'], ['无', '线', '路', '由', '器', '怎', '么', '无', '线', '上', '网'], ['左', '眼', '皮', '跳', '是', '什', '么', '原', '因'], ['部', '落', '战', '争', '怎', '么', '更', '新', '？'], ['这', '个', '空', '气', '净', '化', '器', '有', '用', '吗', '？'], ['看', '图', '猜', '成', '语', '，', '这', '是', '什', '么', '？'], ['找', '工', '作', '网', '站', '哪', '个', '好', '？'], ['问', '发', '型', '，', '男', '生', '。'], ['安', '卓', '手', '机', '怎', '么', '设', '置', '来', '电', '自', '动', '接', '听'], ['部', '落', '冲', '突', '游', '戏', '怎', '么', '找', '回'], ['怎', '么', '才', '能', '下', '载', '穿', '越', '火', '线'], ['你', '点', '击', '详', '情'], ['我', '要', '找', '一', '个', '人', '怎', '么', '找'], ['中', '国', '四', '大', '古', '城', '是', '哪', '些', '？'], ['脸', '上', '痣', '太', '多', '怎', '么', '办', '？'], ['福', '州', '哪', '家', '装', '修', '公', '司', '好'], ['请', '问', '下', '这', '是', '什', '么', '表', '情'], ['大', '限', '什', '么', '意', '思'], ['名', '人', '理', '财', '小', '故', '事', '几', '则'], ['奔', '跑', '吧', '兄', '弟', '里', '的'], ['宝', '盖', '头', '的', '字', '与', '什', '么', '有', '关'], ['下', '雪', '了', '，', '房', '子', '像', '什', '么', '？'], ['一', '本', '官', '场', '小', '说', '的', '名', '字', '？'], ['求', '恋', '爱', '棱', '镜', '漫', '画'], ['类', '似', '于', '植', '物', '大', '战', '僵', '尸', '的', '游', '戏', '有', '哪', '些'], ['这', '是', '什', '么', '动', '画', '啊'], ['日', '本', '爱', '情', '吻', '戏', '动', '漫'], ['哪', '位', '亲', '有', '东', '方', '神', '起', '塞', '班', '岛', '的', '写', '真', '辑', '啊', '？'], ['石', '家', '庄', '天', '气', '如', '何', '？'], ['中', '国', '哪', '里', '的', '地', '方', '最', '美'], ['追', '女', '孩', '该', '怎', '么', '追', '？'], ['高', '中', '数', '学', '问', '题', '，', '数', '列'], ['劝', '告', '你', '不', '听', '是', '什', '么', '成', '语'], ['支', '付', '宝', '为', '什', '么', '不', '能', '实', '名', '认', '证'], ['小', '尾', '巴', '怎', '么', '设', '置'], ['麻', '烦', '您', '点', '击', '链', '接', '看', '看', '的', '，', '辛', '苦', '您', '了', '。'], ['罗', '志', '祥', '的', '发', '型', '叫', '什', '么'], ['红', '豆', '薏', '米', '粥', '减', '肥', '靠', '谱', '吗'], ['大', '写', '的', '万', '字', '，', '怎', '么', '写', '？'], ['网', '易', '新', '闻', '和', '腾', '讯', '新', '闻', '哪', '个', '强'], ['这', '边', '给', '您', '发', '送', '，', '您', '从', '新', '操', '作', '一', '下', '可', '以', '吗', '？'], ['游', '戏', '王',  ...
# [['谁', '知', '道', '她', '是', '网', '络', '美', '女', '吗', '？'], ['人', '和', '畜', '生', '的', '区', '别', '是', '什', '么', '？'], ['男', '孩', '喝', '女', '孩', '的', '尿', '的', '故', '事'], ['这', '种', '图', '片', '是', '用', '什', '么', '软', '件', '制', '作', '的', '？'], ['这', '腰', '带', '是', '什', '么', '牌', '子'], ['什', '么', '牌', '子', '的', '空', '调', '最', '好', '！'], ['校', '花', '的', '贴', '身', '高', '手', '打', '给', '什', '么', '时', '候', '完', '结'], ['移', '动', '手', '机', '可', '以', '改', '成', '电', '信', '手', '机', '吗'], ['手', '机', '微', '信', '内', '容', '可', '以', '同', '步', '到', '电', '脑', '上', '吗'], ['哭', '求', '《', '魔', '术', '脑', '》', '中', '文', '版', '电', '子', '书', '谢', '谢', '你', '们', '了'], ['马', '上', '情', '人', '节', '了', '，', '大', '家', '都', '怎', '么', '安', '排', '情', '人', '节', '的', '行', '程', '啊'], ['求', '桃', '子', '老', '师', '和', '他', '的', '四', '个', '学', '生', '漫', '画'], ['抓', '耙', '仔', '是', '什', '么', '意', '思'], ['这', '个', '表', '情', '叫', '什', '么'], ['介', '绍', '几', '本', '好', '看', '的', '都', '市', '异', '能', '小', '说', '，', '要', '完', '结', '的', '！'], ['一', '只', '蜜', '蜂', '落', '在', '日', '历', '上', '（', '打', '一', '成', '语', '）'], ['一', '盒', '香', '烟', '不', '拆', '开', '能', '存', '放', '多', '久', '？'], ['什', '么', '是', '智', '能', '手', '环'], ['您', '好', '.', '麻', '烦', '您', '截', '图', '全', '屏', '辛', '苦', '您', '了', '.'], ['苏', '州', '达', '方', '电', '子', '有', '限', '公', '司', '联', '系', '方', '式'], ['蛋', '黄', '吃', '多', '了', '有', '什', '么', '坏', '处'], ['从', '龙', '岗', '到', '深', '圳', '华', '夏', '艺', '术', '中', '心', '怎', '么', '坐', '车', '？'], ['西', '安', '下', '雪', '了', '？', '是', '不', '是', '很', '冷', '啊', '?'], ['第', '一', '次', '去', '见', '女', '朋', '友', '父', '母', '该', '如', '何', '表', '现', '？'], ['猪', '的', '护', '心', '肉', '怎', '么', '切'], ['显', '卡', '驱', '动', '安', '装', '不', '了', '，', '为', '什', '么', '？'], ['三', '星', '手', '机', '屏', '幕', '是', '不', '是', '最', '好', '的', '？'], ['左', '嘴', '角', '有', '痣', '的', '男', '人'], ['怎', '样', '买', '液', '晶', '电', '视', '？'], ['亲', '，', '这', '个', '需', '要', '帮', '您', '转', '接', '处', '理', '，', '您', '看', '可', '以', '吗'], ['冬', '天', '爱', '上', '火', '吃', '什', '么', '好', '？'], ['魔', '幻', '手', '机', '第', '三', '部', '什', '么', '时', '候', '上', '映', '？'], ['怎', '么', '把', '手', '机', '弄', '坏', '？', '不', '被', '发', '现', '。'], ['抛', '货', '价', '什', '么', '意', '思'], ['初', '二', '地', '理', '生', '物', '会', '考', '难', '吗', '？'], ['哪', '个', '播', '放', '器', '电', '影', '更', '新', '的', '最', '快'], ['和', '校', '花', '同', '居', '的', '日', '子', '电', '子', '书', 't', 'x', 't', '全', '集', '下', '载'], ['郑', '州', '割', '双', '眼', '皮', '一', '般', '需', '要', '多', '少', '钱'], ['怎', '么', '让', '皮', '肤', '变', '白', '能', '不', '能', '帮', '忙', '？'], ['去', '哪', '个', '网', '站', '买', '正', '品', '化', '妆', '品', '？'], ['帮', '忙', '起', '个', '火', '锅', '店', '名', '字', '千', '万', '不', '要', '复', '制', '！'], ['告', '诉', '我', '关', '于', '异', '界', '女', '神', '的', '小', '说'], ['穿', '越', '火', '线', '这', '些', '装', '备', '要', '多', '少', '钱'], ['q', 'q', '音', '乐', '和', '陌', '陌', '咋', '打', '不', '开', '了', '呢', '?'], ['什', '么', '东', '西', '不', '好', '吃', '？'], ['男', '人', '为', '什', '么', '爱', '美', '女'], ['不', '要', '骂', '明', '星', '很', '多', '人', '就', '是', '你', '们', '逼', '的', '才', '不', '做', '明', '星', '的', '！'], ['求', '网', '络', '游', '戏', '个', '性', '情', '侣', '名', '字', '？'], ['用', '农', '行', '信', '用', '卡', '在', '网', '上', '购', '物', '，', '算', '积', '分', '吗', '？'], ['额', '头', '窄', '，', '适', '合', '做', '什', '么', '发', '型', '？'], ['飞', '机', '是', '什', '么', '意', '思'], ['在', '中', '国', '历', '史', '上', '最', '有', '名', '的', '将', '军', '是', '谁', '？'], ['犯', '太', '岁', '是', '什', '么', '意', '思', '？'], ['梦', '见', '自', '己', '生', '病', '死', '了'], ['四', '川', '城', '市', '职', '业', '学', '院', '怎', '么', '样', '？'], ['梦', '幻', '西', '游', '游', '戏', '名', '字', '谁', '帮', '我', '起', '下'], ['为', '什', '么', '黑', '人', '的', '阴', '茎', '那', '么', '大'], ['沈', '阳', '从', '中', '街', '到', '万', '达', '广', '场', '奥', '体', '店', '得', '多', '长', '时', '间'], ['现', '在', '学', '家', '电', '维', '修', '到', '底', '有', '前', '途', '吗', '?'], ['买', '火', '车', '票', '需', '要', '身', '份', '证', '吗', '？'], ['怎', '样', '知', '道', '自', '己', '驾', '照', '还', '有', '多', '少', '分', '？'], ['今', '天', '离', '过', '年', '还', ' ...
# 加载测试数据集
# 2022-01-19 22:32:10,355 : INFO : PROGRESS: at sentence #50000, processed 532237 words, keeping 3887 word types
# 2022-01-19 22:32:10,368 : INFO : PROGRESS: at sentence #60000, processed 639394 words, keeping 3997 word types
# 2022-01-19 22:32:10,380 : INFO : PROGRESS: at sentence #70000, processed 746367 words, keeping 4102 word types
# 2022-01-19 22:32:10,393 : INFO : PROGRESS: at sentence #80000, processed 852661 words, keeping 4165 word types
# 2022-01-19 22:32:10,406 : INFO : PROGRESS: at sentence #90000, processed 959552 words, keeping 4247 word types
# 2022-01-19 22:32:10,418 : INFO : PROGRESS: at sentence #100000, processed 1065777 words, keeping 4312 word types
# 2022-01-19 22:32:10,431 : INFO : PROGRESS: at sentence #110000, processed 1172764 words, keeping 4371 word types
# 2022-01-19 22:32:10,443 : INFO : PROGRESS: at sentence #120000, processed 1279441 words, keeping 4411 word types
# 2022-01-19 22:32:10,456 : INFO : PROGRESS: at sentence #130000, processed 1385826 words, keeping 4456 word types
# 2022-01-19 22:32:10,471 : INFO : PROGRESS: at sentence #140000, processed 1492470 words, keeping 4489 word types
# 2022-01-19 22:32:10,486 : INFO : PROGRESS: at sentence #150000, processed 1599768 words, keeping 4525 word types
# 2022-01-19 22:32:10,500 : INFO : PROGRESS: at sentence #160000, processed 1706717 words, keeping 4562 word types
# 2022-01-19 22:32:10,516 : INFO : PROGRESS: at sentence #170000, processed 1813446 words, keeping 4587 word types
# 2022-01-19 22:32:10,529 : INFO : PROGRESS: at sentence #180000, processed 1920592 words, keeping 4617 word types
# 2022-01-19 22:32:10,543 : INFO : PROGRESS: at sentence #190000, processed 2027303 words, keeping 4646 word types
# 2022-01-19 22:32:10,556 : INFO : PROGRESS: at sentence #200000, processed 2133868 words, keeping 4668 word types
# 2022-01-19 22:32:10,570 : INFO : PROGRESS: at sentence #210000, processed 2240525 words, keeping 4695 word types
# 2022-01-19 22:32:10,583 : INFO : PROGRESS: at sentence #220000, processed 2346681 words, keeping 4717 word types
# 2022-01-19 22:32:10,596 : INFO : PROGRESS: at sentence #230000, processed 2453679 words, keeping 4735 word types
# 2022-01-19 22:32:10,609 : INFO : PROGRESS: at sentence #240000, processed 2560945 words, keeping 4756 word types
# 2022-01-19 22:32:10,622 : INFO : PROGRESS: at sentence #250000, processed 2673504 words, keeping 4777 word types
# 2022-01-19 22:32:10,635 : INFO : PROGRESS: at sentence #260000, processed 2784874 words, keeping 4795 word types
# 2022-01-19 22:32:10,648 : INFO : PROGRESS: at sentence #270000, processed 2896835 words, keeping 4818 word types
# 2022-01-19 22:32:10,661 : INFO : PROGRESS: at sentence #280000, processed 3008315 words, keeping 4834 word types
# 2022-01-19 22:32:10,674 : INFO : PROGRESS: at sentence #290000, processed 3119712 words, keeping 4852 word types
# 2022-01-19 22:32:10,687 : INFO : PROGRESS: at sentence #300000, processed 3232510 words, keeping 4869 word types
# 2022-01-19 22:32:10,700 : INFO : PROGRESS: at sentence #310000, processed 3344333 words, keeping 4885 word types
# 2022-01-19 22:32:10,714 : INFO : PROGRESS: at sentence #320000, processed 3456110 words, keeping 4897 word types
# 2022-01-19 22:32:10,728 : INFO : PROGRESS: at sentence #330000, processed 3568516 words, keeping 4903 word types
# 2022-01-19 22:32:10,742 : INFO : PROGRESS: at sentence #340000, processed 3680409 words, keeping 4918 word types
# 2022-01-19 22:32:10,755 : INFO : PROGRESS: at sentence #350000, processed 3792812 words, keeping 4929 word types
# 2022-01-19 22:32:10,769 : INFO : PROGRESS: at sentence #360000, processed 3904280 words, keeping 4939 word types
# 2022-01-19 22:32:10,783 : INFO : PROGRESS: at sentence #370000, processed 4015976 words, keeping 4950 word types
# 2022-01-19 22:32:10,797 : INFO : PROGRESS: at sentence #380000, processed 4128315 words, keeping 4958 word types
# 2022-01-19 22:32:10,811 : INFO : PROGRESS: at sentence #390000, processed 4241168 words, keeping 4968 word types
# 2022-01-19 22:32:10,825 : INFO : PROGRESS: at sentence #400000, processed 4353289 words, keeping 4974 word types
# 2022-01-19 22:32:10,839 : INFO : PROGRESS: at sentence #410000, processed 4465189 words, keeping 4989 word types
# 2022-01-19 22:32:10,854 : INFO : PROGRESS: at sentence #420000, processed 4577682 words, keeping 4994 word types
# 2022-01-19 22:32:10,868 : INFO : PROGRESS: at sentence #430000, processed 4689912 words, keeping 5001 word types
# 2022-01-19 22:32:10,881 : INFO : PROGRESS: at sentence #440000, processed 4802119 words, keeping 5014 word types
# 2022-01-19 22:32:10,895 : INFO : PROGRESS: at sentence #450000, processed 4914410 words, keeping 5020 word types
# 2022-01-19 22:32:10,908 : INFO : PROGRESS: at sentence #460000, processed 5026209 words, keeping 5026 word types
# 2022-01-19 22:32:10,922 : INFO : PROGRESS: at sentence #470000, processed 5138990 words, keeping 5032 word types
# 2022-01-19 22:32:10,937 : INFO : PROGRESS: at sentence #480000, processed 5254260 words, keeping 5042 word types
# 2022-01-19 22:32:10,952 : INFO : PROGRESS: at sentence #490000, processed 5379245 words, keeping 5053 word types
# 2022-01-19 22:32:10,966 : INFO : PROGRESS: at sentence #500000, processed 5490235 words, keeping 5063 word types
# 2022-01-19 22:32:10,978 : INFO : PROGRESS: at sentence #510000, processed 5586996 words, keeping 5078 word types
# 2022-01-19 22:32:10,990 : INFO : PROGRESS: at sentence #520000, processed 5685254 words, keeping 5088 word types
# 2022-01-19 22:32:10,991 : INFO : collected 5088 word types from a corpus of 5686461 raw words and 520130 sentences
# 2022-01-19 22:32:10,991 : INFO : Creating a fresh vocabulary
# 2022-01-19 22:32:11,005 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 4169 unique words (81.937893081761%% of original 5088, drops 919)', 'datetime': '2022-01-19T22:32:11.004391', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-01-19 22:32:11,005 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 5684200 word corpus (99.9602388902342%% of original 5686461, drops 2261)', 'datetime': '2022-01-19T22:32:11.005392', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-01-19 22:32:11,033 : INFO : deleting the raw counts dictionary of 5088 items
# 2022-01-19 22:32:11,034 : INFO : sample=0.001 downsamples 62 most-common words
# 2022-01-19 22:32:11,034 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 4390458.337698577 word corpus (77.2%% of prior 5684200)', 'datetime': '2022-01-19T22:32:11.034404', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-01-19 22:32:11,070 : INFO : estimated required memory for 4169 words and 300 dimensions: 12090100 bytes
# 2022-01-19 22:32:11,070 : INFO : resetting layer weights
# 2022-01-19 22:32:11,077 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-01-19T22:32:11.077403', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'build_vocab'}
# 2022-01-19 22:32:11,078 : INFO : Word2Vec lifecycle event {'msg': 'training model with 1 workers on 4169 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=5', 'datetime': '2022-01-19T22:32:11.078406', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2022-01-19 22:32:12,100 : INFO : EPOCH 1 - PROGRESS: at 4.51% examples, 188040 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:13,138 : INFO : EPOCH 1 - PROGRESS: at 9.57% examples, 197684 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:14,165 : INFO : EPOCH 1 - PROGRESS: at 14.42% examples, 199173 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:15,179 : INFO : EPOCH 1 - PROGRESS: at 19.47% examples, 202318 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:16,185 : INFO : EPOCH 1 - PROGRESS: at 24.51% examples, 204637 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:17,225 : INFO : EPOCH 1 - PROGRESS: at 29.19% examples, 202525 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:18,245 : INFO : EPOCH 1 - PROGRESS: at 34.03% examples, 202652 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:19,246 : INFO : EPOCH 1 - PROGRESS: at 38.90% examples, 203204 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:20,266 : INFO : EPOCH 1 - PROGRESS: at 43.95% examples, 204120 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:21,303 : INFO : EPOCH 1 - PROGRESS: at 48.84% examples, 204622 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:22,339 : INFO : EPOCH 1 - PROGRESS: at 53.66% examples, 205067 words/s, in_qsize 2, out_qsize 0
# 2022-01-19 22:32:23,353 : INFO : EPOCH 1 - PROGRESS: at 58.28% examples, 205196 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:24,369 : INFO : EPOCH 1 - PROGRESS: at 62.93% examples, 205275 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:25,372 : INFO : EPOCH 1 - PROGRESS: at 67.37% examples, 204971 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:26,377 : INFO : EPOCH 1 - PROGRESS: at 71.85% examples, 204668 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:27,399 : INFO : EPOCH 1 - PROGRESS: at 76.46% examples, 204690 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:28,426 : INFO : EPOCH 1 - PROGRESS: at 81.09% examples, 204659 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:29,426 : INFO : EPOCH 1 - PROGRESS: at 85.53% examples, 204510 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:30,460 : INFO : EPOCH 1 - PROGRESS: at 90.16% examples, 204429 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:31,492 : INFO : EPOCH 1 - PROGRESS: at 94.32% examples, 204002 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:32,519 : INFO : EPOCH 1 - PROGRESS: at 99.61% examples, 204054 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:32,585 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-19 22:32:32,585 : INFO : EPOCH - 1 : training on 5686461 raw words (4389488 effective words) took 21.5s, 204115 effective words/s
# 2022-01-19 22:32:33,590 : INFO : EPOCH 2 - PROGRESS: at 4.87% examples, 206619 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:34,604 : INFO : EPOCH 2 - PROGRESS: at 9.74% examples, 205631 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:35,640 : INFO : EPOCH 2 - PROGRESS: at 14.60% examples, 203832 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:36,644 : INFO : EPOCH 2 - PROGRESS: at 18.57% examples, 195048 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:37,658 : INFO : EPOCH 2 - PROGRESS: at 23.43% examples, 197075 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:38,690 : INFO : EPOCH 2 - PROGRESS: at 28.47% examples, 198976 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:39,703 : INFO : EPOCH 2 - PROGRESS: at 33.50% examples, 200904 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:40,713 : INFO : EPOCH 2 - PROGRESS: at 38.36% examples, 201424 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:41,728 : INFO : EPOCH 2 - PROGRESS: at 43.23% examples, 201769 words/s, in_qsize 2, out_qsize 0
# 2022-01-19 22:32:42,752 : INFO : EPOCH 2 - PROGRESS: at 47.98% examples, 202034 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:43,776 : INFO : EPOCH 2 - PROGRESS: at 52.62% examples, 202237 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:44,814 : INFO : EPOCH 2 - PROGRESS: at 57.43% examples, 202847 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:45,824 : INFO : EPOCH 2 - PROGRESS: at 61.90% examples, 202605 words/s, in_qsize 2, out_qsize 0
# 2022-01-19 22:32:46,861 : INFO : EPOCH 2 - PROGRESS: at 66.52% examples, 202543 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:47,878 : INFO : EPOCH 2 - PROGRESS: at 71.16% examples, 202794 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:48,881 : INFO : EPOCH 2 - PROGRESS: at 75.61% examples, 202697 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:49,886 : INFO : EPOCH 2 - PROGRESS: at 79.88% examples, 202125 words/s, in_qsize 1, out_qsize 0
# 2022-01-19 22:32:50,888 : INFO : EPOCH 2 - PROGRESS: at 84.34% examples, 202098 words/s, in_qsize 1, out_qsize 0

# %%
##测试embedding
from gensim.models import Word2Vec
w2v_path = "models/w2v_all300.model"


embedding = Word2Vec.load(w2v_path)
print(type(embedding))
print(embedding)
# print(embedding['i'])
for i,word in enumerate(embedding.wv.key_to_index ):
  print(word)
