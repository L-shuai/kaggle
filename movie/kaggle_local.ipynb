# %% [markdown]
# # Bag of Words Meets Bags of Popcorn

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("dataset/unlabeledTrainData.tsv",sep = "\t",error_bad_lines=False)
df
# Out:
# b'Skipping line 43043: expected 2 fields, saw 3\n'
#             id                                             review
# 0       9999_0  Watching Time Chasers, it obvious that it was ...
# 1      45057_0  I saw this film about 20 years ago and remembe...
# 2      15561_0  Minor Spoilers<br /><br />In New York, Joan Ba...
# 3       7161_0  I went to see this film with a great deal of e...
# 4      43971_0  Yes, I agree with everyone on this site this m...
# 5      36495_0  Jennifer Ehle was sparkling in \Pride and Prej...
# 6      49472_0  Amy Poehler is a terrific comedian on Saturday...
# 7      36693_0  A plane carrying employees of a large biotech ...
# 8        316_0  A well made, gritty science fiction movie, it ...
# 9      32454_0  Incredibly dumb and utterly predictable story ...
# 10     37128_0  After reading the comments for this movie, I a...
# 11     19439_0  It's hard to describe Elfen Lied to someone wh...
# 12     10760_0  Of all the bile-inducing vomitoriums to squeez...
# 13     15073_0  This is quite an underrated Hitchcock movie. W...
# 14     33119_0  Being a huge Gary Oldman fan, I had high hopes...
# 15     38735_0  For the most part the acting was poorly done (...
# 16     12041_0  Ram Gopal Varma does it again yet another movi...
# 17     41565_0  I gave it 2 for some attempt at historical det...
# 18     48612_0  I wanted to watch this one sense I am a fan of...
# 19     17525_0  Che is a good film for chronicling the events ...
# 20     32062_0  This film is very disturbing. It reminded me o...
# 21     48625_0  Let me put it this way. I love bad movies. I p...
# 22     48176_0  From the combined ministries of Jack and Rexel...
# 23     16232_0  Ghost World is one of the better teen or commi...
# 24     12528_0  Outstanding film dealing with a 16 year old wh...
# 25     39976_0  This movie did play like a dream or maybe even...
# 26     25857_0  This film is supposedly based on the true acco...
# 27     10552_0  I know that cartoons aimed towards adults gene...
# 28     26437_0  ...but what a disappointment. The acting was s...
# 29     16262_0  As a long-time Holmes fan, and particularly of...
# ...        ...                                                ...
# 49968  25941_0  Wouldn't suit all tastes, but if you like it y...
# 49969  36778_0  As a great fan of Dwight Yoakam's music as wel...
# 49970  37114_0  I'm a huge fan of Whoopi and have seen all of ...
# 49971  11962_0  It not very often that I go to the same movie ...
# 49972  32293_0  I, like most, worried that it would degrade \B...
# 49973   7005_0  This movie makes no bones about what it is and...
# 49974    112_0  The eyebrow-wagging Lionel Q. Deveraux (Grouch...
# 49975  46123_0  There maybe spoilers in the following; if you ...
# 49976  10628_0  This is one of my favorite films. <br /><br />...
# 49977  22572_0  A novelist who could find a funny side of a di...
# 49978  40601_0  This is the worst drivel I've ever seen come t...
# 49979  31509_0  \Jaguar Lives\" is very slow and plodding ente...
# 49980  33703_0  This should have been better, much better. A f...
# 49981   7379_0  Look at the number of film festival awards \Th...
# 49982  29370_0  This movie is one of the best of all time.Firs...
# 49983  27604_0  The earliest episodes with John Amos as the ca...
# 49984   9197_0  I've been looking for this movie since I becam...
# 49985  34018_0  OK, this isn't a good film by any stretch of t...
# 49986  15625_0  It is arguably the most boring film I've ever ...
# 49987  35740_0  Oh joy,, another foreign torture/bloody movie ...
# 49988  20947_0  In 1994, a year that gave us Forrest Gump, Pul...
# 49989   7432_0  http://eattheblinds.blogspot.com/<br /><br />I...
# 49990  35236_0  Taste the Blood of Dracula marks a first for H...
# 49991  12075_0  There were some aspects of this movie I really...
# 49992  23455_0  Look, I don't know what people have against Ed...
# 49993  18984_0  The original Man Eater by Joe D'Amato is somew...
# 49994  16433_0  When Home Box Office was in it's early days mo...
# 49995  16006_0  Griffin Dunne was born into a cultural family....
# 49996  40155_0  Not a bad story, but the low budget rears its ...
# 49997  35270_0  This not-very-good mummy-alien flick does feat...
#
# [49998 rows x 2 columns]

# %% [markdown]
# ## Utils

# %%
#utils
import torch
import numpy as np
import pandas as pd
import torch.optim as optim
import torch.nn.functional as F


label_train_path = "dataset/labeledTrainData.tsv"
unlabel_train_path = "dataset/unlabeledTrainData.tsv"
test_path = "dataset/testData.tsv"

def load_training_data(path='labeledTrainData.tsv'):  
    #global x,y
    # 把training时需要的data打开
    # 如果是'training_labe|l.txt'，需要获取label，如果是'training_nolabel.txt'，不需要获取label
    if(path == "dataset/labeledTrainData.tsv"):
        df = pd.read_csv("dataset/labeledTrainData.tsv",sep = "\t")
        #display(df.head())
        x = df['review'].apply(lambda x: x.strip().split(" "))
        x = list(x)
        y = df["sentiment"]  #二维的list
        y = list(y)   #一维的list
        return x, y
    else:
        df = pd.read_csv("dataset/unlabeledTrainData.tsv",sep = "\t",error_bad_lines=False)
        x = df['review'].apply(lambda x: x.strip().split(" "))
        x = list(x)
        return x

def load_testing_data(path='dataset/testData.tsv'):   #约55万
    # 把testing時需要的data讀進來
    df = pd.read_csv("dataset/testData.tsv",sep = "\t")
    #display(df.head())
    x = df['review'].apply(lambda x: x.strip().split(" "))
    x = list(x)
    return x  # X形如[["i","am","here"], ["he","loves","it"]]

def evaluation(outputs, labels):
    #outputs => probability (float)
    #labels => labels
    outputs[outputs>=0.5] = 1 # 大於等於0.5為有惡意
    outputs[outputs<0.5] = 0 # 小於0.5為無惡意
    correct = torch.sum(torch.eq(outputs, labels)).item()
    return correct

# %% [markdown]
# ## 训练词向量

# %%
#训练词向量
train_x,y = load_training_data(label_train_path)
average_sentence_length = 0
for sen in train_x:
    average_sentence_length += len(sen)
average_sentence_length /= len(train_x)
print("训练集平均句子长度：",average_sentence_length)
# Out:
# 训练集平均句子长度： 233.78624

# %%
#训练word2Vec
import os
import numpy as np
import pandas as pd
import argparse
from gensim.models import word2vec

# 导入日志模块 创建更漂亮的输出消息
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',level=logging.INFO)

path_prefix = "model/"
def train_word2vec(x):
  # 训练word embedding
  """
  Embedding 层的输入是一个二维整数张量， 形状为（samples，sequence_length），即（样本数，序列长度）
  Embedding 层输出是（samples，sequence_length，embedding_dimensionality） 的三维浮点数张量。
  较短的序列应该用 0 填充，较长的序列应该被截断，保证输入的序列长度是相同的
  """
  model = word2vec.Word2Vec(x,vector_size=250,window=5,min_count=5,workers=12,epochs=10,sg=1) #iter is epochs
  return model

l = os.listdir()
if "w2v_all.model" not in l:  #如果模型还未创建
  print("加载训练数据")
  train_x,y = load_training_data(label_train_path)
  train_x_no_label = load_training_data(unlabel_train_path)

  print("加载测试数据集")
  test_x = load_testing_data(test_path)
  #训练word embedding时可以将带标签和不代标签的都输入进去   因为这个越多越好   与标签无关
  model = train_word2vec(train_x+train_x_no_label+test_x)
  print("保存模型")
  model.save(os.path.join(path_prefix,"w2v_all.model"))
# Out:
# 加载训练数据
# b'Skipping line 43043: expected 2 fields, saw 3\n'
# 加载测试数据集
# 2022-01-17 14:15:21,561 : INFO : collecting all words and their counts
# 2022-01-17 14:15:21,561 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-17 14:15:21,904 : INFO : PROGRESS: at sentence #10000, processed 2354823 words, keeping 161626 word types
# 2022-01-17 14:15:22,218 : INFO : PROGRESS: at sentence #20000, processed 4686267 words, keeping 249660 word types
# 2022-01-17 14:15:22,528 : INFO : PROGRESS: at sentence #30000, processed 7008953 words, keeping 325138 word types
# 2022-01-17 14:15:22,888 : INFO : PROGRESS: at sentence #40000, processed 9345154 words, keeping 393688 word types
# 2022-01-17 14:15:23,224 : INFO : PROGRESS: at sentence #50000, processed 11712399 words, keeping 457537 word types
# 2022-01-17 14:15:23,602 : INFO : PROGRESS: at sentence #60000, processed 14063739 words, keeping 515341 word types
# 2022-01-17 14:15:23,954 : INFO : PROGRESS: at sentence #70000, processed 16393236 words, keeping 567943 word types
# 2022-01-17 14:15:24,295 : INFO : PROGRESS: at sentence #80000, processed 18701365 words, keeping 619740 word types
# 2022-01-17 14:15:24,638 : INFO : PROGRESS: at sentence #90000, processed 20989762 words, keeping 668733 word types
# 2022-01-17 14:15:24,999 : INFO : collected 715302 word types from a corpus of 23278863 raw words and 99998 sentences
# 2022-01-17 14:15:25,000 : INFO : Creating a fresh vocabulary
# 2022-01-17 14:15:25,499 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 121343 unique words (16.96388378614907%% of original 715302, drops 593959)', 'datetime': '2022-01-17T14:15:25.499018', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-01-17 14:15:25,499 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 22451701 word corpus (96.44672508274996%% of original 23278863, drops 827162)', 'datetime': '2022-01-17T14:15:25.499018', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-01-17 14:15:26,069 : INFO : deleting the raw counts dictionary of 715302 items
# 2022-01-17 14:15:26,085 : INFO : sample=0.001 downsamples 43 most-common words
# 2022-01-17 14:15:26,085 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 17522990.80408003 word corpus (78.0%% of prior 22451701)', 'datetime': '2022-01-17T14:15:26.085047', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-01-17 14:15:27,013 : INFO : estimated required memory for 121343 words and 250 dimensions: 303357500 bytes
# 2022-01-17 14:15:27,014 : INFO : resetting layer weights
# 2022-01-17 14:15:27,145 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-01-17T14:15:27.145277', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'build_vocab'}
# 2022-01-17 14:15:27,145 : INFO : Word2Vec lifecycle event {'msg': 'training model with 12 workers on 121343 vocabulary and 250 features, using sg=1 hs=0 sample=0.001 negative=5 window=5', 'datetime': '2022-01-17T14:15:27.145277', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2022-01-17 14:15:28,191 : INFO : EPOCH 1 - PROGRESS: at 1.88% examples, 331021 words/s, in_qsize 24, out_qsize 0
# 2022-01-17 14:15:29,203 : INFO : EPOCH 1 - PROGRESS: at 3.88% examples, 344368 words/s, in_qsize 23, out_qsize 0
# 2022-01-17 14:15:30,285 : INFO : EPOCH 1 - PROGRESS: at 6.03% examples, 345341 words/s, in_qsize 24, out_qsize 0
# 2022-01-17 14:15:31,287 : INFO : EPOCH 1 - PROGRESS: at 8.14% examples, 352775 words/s, in_qsize 23, out_qsize 0
# 2022-01-17 14:15:32,287 : INFO : EPOCH 1 - PROGRESS: at 10.33% examples, 358648 words/s, in_qsize 23, out_qsize 0
# 2022-01-17 14:15
: INFO : worker thread finished; awaiting finish of 11 more threads
# 2022-01-17 14:23:54,648 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2022-01-17 14:23:54,710 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2022-01-17 14:23:54,710 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2022-01-17 14:23:54,710 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2022-01-17 14:23:54,710 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2022-01-17 14:23:54,758 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2022-01-17 14:23:54,764 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2022-01-17 14:23:54,768 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-01-17 14:23:54,779 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-17 14:23:54,789 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-17 14:23:54,796 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-17 14:23:54,797 : INFO : EPOCH - 10 : training on 23278863 raw words (17522844 effective words) took 49.1s, 356787 effective words/s
# 2022-01-17 14:23:54,797 : INFO : Word2Vec lifecycle event {'msg': 'training on 232788630 raw words (175225513 effective words) took 507.6s, 345178 effective words/s', 'datetime': '2022-01-17T14:23:54.797746', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2022-01-17 14:23:54,798 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=121343, vector_size=250, alpha=0.025)', 'datetime': '2022-01-17T14:23:54.798747', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'created'}
# 2022-01-17 14:23:54,800 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'model/w2v_all.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-01-17T14:23:54.800747', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'saving'}
# 2022-01-17 14:23:54,800 : INFO : storing np array 'vectors' to model/w2v_all.model.wv.vectors.npy
# 2022-01-17 14:23:54,866 : INFO : storing np array 'syn1neg' to model/w2v_all.model.syn1neg.npy
# 2022-01-17 14:23:54,960 : INFO : not storing attribute cum_table
# 保存模型
# 2022-01-17 14:23:55,016 : INFO : saved model/w2v_all.model

# %% [markdown]
# ## embedding和word2vec详解
# Embedding 层的输入是一个**二维整数张量**， 形状为（samples，sequence_length），即（样本数，序列长度）
# >较短的序列应该用 0 填充，较长的序列应该被截断，保证输入的序列长度是相同的
# Embedding 层输出是（samples，sequence_length，embedding_dimensionality） 的三维浮点数张量。
#
# * 首先，我们需要对文本进行分词处理，然后对分词结果进行序列化
# * 再统一输入的序列长度，最后把统一长度的序列化结果输入到 Embedding 层中
#
# ![embedding过程](./dataset/otherData/img.png)
#
#
# gensim库提供了一个word2vec的实现，我们使用几个API就可以方便地完成word2vec

# %%
from gensim.models import Word2Vec
w2v_path = "model/w2v_all.model"


embedding = Word2Vec.load(w2v_path)
print(type(embedding))
print(embedding)
# print(embedding['i'])
for i,word in enumerate(embedding.wv.key_to_index ):
  print(word)
# Out:
# 2022-01-17 14:25:11,053 : INFO : loading Word2Vec object from model/w2v_all.model
# 2022-01-17 14:25:11,100 : INFO : loading wv recursively from model/w2v_all.model.wv.* with mmap=None
# 2022-01-17 14:25:11,100 : INFO : loading vectors from model/w2v_all.model.wv.vectors.npy with mmap=None
# 2022-01-17 14:25:11,147 : INFO : loading syn1neg from model/w2v_all.model.syn1neg.npy with mmap=None
# 2022-01-17 14:25:11,194 : INFO : setting ignored attribute cum_table to None
# 2022-01-17 14:25:12,339 : INFO : Word2Vec lifecycle event {'fname': 'model/w2v_all.model', 'datetime': '2022-01-17T14:25:12.339479', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'loaded'}
# <class 'gensim.models.word2vec.Word2Vec'>
# Word2Vec(vocab=121343, vector_size=250, alpha=0.025)
# the
# a
# and
# of
# to
# is
# in
# I
# that
# this
# it
# /><br
# was
# as
# with
# for
# The
# but
# on
# movie
# are
# film
# his
# have
# not
# be
# you
# by
# he
# at
# one
# an
# from
# who
# like
# they
# all
# has
# just
# so
# or
# about
# her
# out
# some
# very
# more
# This
# would
# what
# when
# good
# their
# if
# only
# up
# really
# It
# had
# it's
# can
# even
# which
# were
# see
# no
# my
# than
# she
# there
# been
# -
# into
# get
# much
# will
# story
# because
# other
# most
# time
# make
# we
# me
# could
# do
# also
# how
# />The
# first
# people
# its
# great
# any
# don't
# made
# bad
# think
# him
# being
# <br
# many
# never
# then
# two
# where
# too
# after
# But
# little
# way
# And
# them
# well
# your
# watch
# characters
# know
# It's
# does
# character
# it.
# did
# seen
# movie.
# movies
# love
# best
# ever
# A
# films
# plot
# In
# over
# should
# still
# these
# off
# such
# acting
# better
# show
# He
# i
# If
# film.
# those
# doesn't
# something
# say
# through
# go
# didn't
# makes
# scene
# movie,
# film,
# find
# There
# real
# scenes
# going
# I'm
# back
# watching
# few
# actually
# same
# />I
# lot
# &
# life
# while
# look
# thing
# every
# quite
# want
# why
# end
# seems
# nothing
# can't
# pretty
# man
# got
# old
# another
# actors
# give
# between
# years
# take
# part
# before
# thought
# may
# around
# it,
# young
# things
# gets
# I've
# whole
# own
# isn't
# must
# saw
# without
# always
# almost
# both
# work
# They
# might
# down
# cast
# bit
# come
# horror
# enough
# new
# us
# least
# director
# feel
# though
# big
# here
# am
# probably
# funny
# fact
# As
# long
# far
# found
# action
# last
# kind
# rather
# original
# that's
# trying
# since
# interesting
# now
# each
# comes
# anything
# What
# You
# he's
# done
# making
# our
# played
# worst
# main
# believe
# guy
# right
# put
# She
# role
# goes
# point
# worth
# plays
# />This
# having
# looks
# wasn't
# music
# looking
# takes
# seem
# hard
# different
# script
# minutes
# performance
# series
# When
# shows
# watched
# world
# anyone
# TV
# away
# especially
# during
# yet
# family
# sure
# comedy
# American
# someone
# times
# set
# three
# there's
# woman
# left
# John
# fun
# used
# girl
# simply
# completely
# time.
# you're
# special
# seeing
# One
# play
# For
# reason
# Not
# --
# sense
# use
# again
# So
# need
# idea
# \"The
# everything
# until
# true
# place
# help
# DVD
# read
# getting
# ending
# truly
# recommend
# given
# try
# came
# couple
# We
# once
# effects
# job
# less
# rest
# everyone
# money
# keep
# gives
# nice
# high
# said
# second
# tell
# All
# That
# beautiful
# half
# shot
# understand
# went
# actor
# enjoy
# audience
# version
# excellent
# poor
# along
# start
# playing
# couldn't
# himself
# become
# My
# 2
# fan
# full
# (and
# screen
# together
# However,
# supposed
# entire
# liked
# doing
# small
# early
# THE
# all,
# Hollywood
# definitely
# let
# next
# against
# felt
# time,
# often
# absolutely
# certainly
# seemed
# maybe
# several
# wife
# is,
# book
# sort
# After
# Even
# day
# becomes
# remember
# At
# later
# short
# totally
# camera
# able
# else
# year
# human
# black
# His
# waste
# 10
# performances
# piece
# wanted
# instead
# men
# production
# kids
# although
# course
# wonderful
# women
# loved
# hope
# them.
# .
# that,
# called
# tries
# friends
# 
# top
# line
# based
# wants
# person
# sex
# live
# home
# cool
# too.
# (which
# killing
# word
# light
# out,
# characters.
# difficult
# keeps
# famous
# sequence
# means
# (or
# towards
# Richard
# you've
# hand
# Peter
# who's
# Its
# five
# career
# stand
# problems
# straight
# leads
# deal
# />It's
# 1
# ridiculous
# sexual
# filmed
# ten
# personal
# poorly
# various
# on,
# cinematography
# move
# doubt
# reality
# forced
# possibly
# hero
# realize
# room
# roles
# comments
# power
# Most
# theme
# blood
# apparently
# age
# These
# brings
# emotional
# meets
# An
# level
# fairly
# Like
# figure
# hilarious
# 4
# possible
# overall
# Is
# whom
# NOT
# gore
# brother
# manages
# alone
# nor
# Tom
# hell
# ones
# interested
# message
# reading
# dialog
# Also
# incredibly
# review
# scenes,
# songs
# rent
# enjoyable
# gay
# moving
# novel
# television
# write
# appear
# team
# begin
# Paul
# parents
# country
# He's
# say,
# leading
# male
# needed
# reviews
# subject
# feature
# somehow
# total
# meant
# worked
# up.
# episodes
# though,
# points
# gone
# create
# sequel
# words
# up,
# features
# tale
# writer
# form
# effort
# viewers
# watch.
# meet
# scene,
# pay
# average
# eventually
# storyline
# Dr.
# spent
# third
# open
# imagine
# particular
# premise
# forget
# plenty
# expected
# First
# expecting
# Japanese
# older
# political
# herself
# hold
# 20
# work.
# minute
# better.
# follow
# Also,
# show.
# future
# scary
# front
# attempts
# there.
# footage
# dramatic
# however
# uses
# caught
# powerful
# decides
# crew
# telling
# soundtrack
# crime
# sequences
# hardly
# York
# comment
# (a
# former
# unique
# crap
# what's
# William
# portrayed
# weak
# fails
# memorable
# deserves
# viewing
# ...
# slightly
# plain
# Who
# By
# (who
# fast
# writers
# check
# you.
# Or
# release
# forward
# result
# times,
# etc.
# deep
# disappointed
# />
# class
# quickly
# copy
# large
# Joe
# amount
# waiting
# sounds
# her,
# outside
# cheesy
# city
# Lee
# realistic
# perfectly
# question
# badly
# Oscar
# sees
# there,
# agree
# Great
# created
# Yes,
# dull
# inside
# admit
# fantastic
# character.
# animation
# talented
# rich
# appreciate
# spend
# monster
# editing
# visual
# predictable
# people,
# period
# ways
# entirely
# earlier
# fighting
# German
# social
# biggest
# wait
# decide
# Italian
# stage
# follows
# portrayal
# atmosphere
# ask
# pure
# wasted
# actors,
# filled
# miss
# unless
# filmmakers
# battle
# material
# box
# recent
# plot.
# comedy,
# involving
# said,
# />What
# you,
# fit
# OF
# rating
# missing
# lame
# wrote
# But,
# people.
# seriously
# great,
# compared
# surprise
# showed
# likes
# theater
# familiar
# common
# present
# setting
# weird
# suspense
# popular
# weren't
# free
# ended
# background
# 'The
# hands
# years.
# runs
# whatever
# War
# moves
# Unfortunately,
# following
# cop
# mystery
# thriller
# Well
# work,
# thinks
# eye
# made.
# situation
# believable
# barely
# screenplay
# in.
# ago
# avoid
# laughing
# general
# married
# man,
# ideas
# directors
# entertainment
# (in
# break
# too,
# members
# leaving
# please
# cover
# scenes.
# credits
# screen.
# opinion
# bought
# nature
# dog
# Man
# show,
# hot
# odd
# sorry
# clever
# basic
# considering
# Disney
# positive
# creepy
# be.
# sister
# suddenly
# dance
# Unfortunately
# so.
# spot
# (like
# happening
# himself.
# bottom
# born
# producer
# land
# today's
# moments,
# (if
# hidden
# bits
# gorgeous
# driving
# holes
# dealing
# technical
# them.<br
# current
# pulled
# vampire
# marriage
# dialogue,
# forgotten
# director's
# week
# together,
# Jerry
# hadn't
# 6
# down.
# relationships
# cliché
# color
# phone
# captured
# ghost
# gonna
# lies
# bigger
# disappointing
# love.
# discovers
# family,
# deals
# creature
# Yet
# see.
# CGI
# entertaining.
# growing
# terrible.
# charm
# personally
# screen,
# confusing
# expectations
# flying
# speaking
# flick.
# music.
# really,
# involves
# plane
# trash
# addition
# relate
# wonderfully
# hopes
# bloody
# desperate
# featuring
# scientist
# angry
# with,
# Alan
# suspect
# opens
# psychological
# humor,
# ago,
# pain
# Allen
# emotion
# starting
# dying
# brutal
# original.
# genuinely
# Still,
# short,
# Smith
# Don
# Stephen
# unknown
# House
# detail
# victims
# noticed
# pictures
# father,
# teacher
# fan,
# regular
# guy,
# foreign
# murders
# intriguing
# apartment
# arts
# century
# double
# listen
# today.
# unable
# finished
# to,
# impact
# overly
# Sean
# shocking
# are,
# Was
# />You
# Everyone
# heads
# latter
# alive
# European
# breaks
# agent
# cinema.
# commentary
# Anyway,
# who,
# low-budget
# food
# for.
# wild
# terribly
# met
# soul
# forces
# Jean
# Which
# Howard
# epic
# 100
# kinda
# loses
# Dennis
# (The
# mistake
# oh
# finish
# reach
# capable
# point.
# lighting
# wooden
# Tim
# drama,
# ultimate
# itself.
# necessary
# />While
# fiction
# garbage
# cops
# Adam
# capture
# unbelievable
# genre.
# content
# actions
# lacking
# adults
# gangster
# loose
# Thomas
# conclusion
# majority
# mind.
# affair
# folks
# through.
# bed
# bar
# grew
# sadly
# proved
# industry
# dangerous
# trailer
# Last
# Before
# knowledge
# Instead,
# continues
# stock
# zombies
# 70's
# lover
# twenty
# fights
# army
# flicks
# ugly
# therefore
# remarkable
# personality
# hospital
# allows
# /
# dies
# remain
# issue
# originally
# crappy
# Let's
# friends,
# direction,
# Brian
# done,
# cat
# hotel
# childhood
# pair
# like,
# described
# date
# (played
# bright
# eat
# okay
# whilst
# \"
# criminal
# leader
# received
# utter
# night,
# Hitchcock
# months
# ran
# murdered
# enough.
# dad
# Anthony
# Western
# right,
# steal
# energy
# steals
# Johnny
# ago.
# boss
# Mr
# loving
# winning
# watching.
# dreams
# explanation
# />"
# portrays
# saved
# see,
# death.
# (even
# VHS
# occasionally
# Gary
# asking
# standing
# station
# seconds
# vote
# higher
# finest
# discovered
# Spanish
# talks
# more,
# Paris
# portray
# Williams
# nicely
# virtually
# roles.
# scared
# sign
# movie?
# twice
# deserved
# combination
# law
# pleasure
# meeting
# they've
# manner
# references
# />Overall,
# aside
# Bond
# travel
# :
# bringing
# largely
# believes
# collection
# (for
# Jeff
# whenever
# himself,
# Steven
# anybody
# memory
# Overall,
# somebody
# sex,
# painfully
# remembered
# visit
# performances.
# grow
# sell
# below
# others.
# jump
# place,
# over.
# wrong,
# area
# super
# reviewers
# reason,
# See
# provided
# erotic
# inept
# Broadway
# picture,
# term
# medical
# device
# sold
# harsh
# beloved
# Queen
# sinister
# true.
# Sir
# line.
# something,
# training
# BBC
# struggles
# Lloyd
# gritty
# introduction
# listening
# hint
# Mickey
# thousands
# believable.
# head.
# mindless
# Park
# face,
# mob
# shoots
# again.<br
# roll
# suspense,
# lonely
# La
# everyday
# faith
# horrible,
# nonsense
# attempted
# UK
# Laura
# increasingly
# dinner
# campy
# seeking
# stops
# President
# ways.
# happened.
# real,
# Victor
# score,
# opposed
# brother,
# on.<br
# suspenseful
# (of
# spoof
# pity
# factor
# section
# amazing.
# u
# Wars
# like.
# dull,
# that?
# excitement
# hiding
# Albert
# legend
# fallen
# execution
# sorts
# prime
# screening
# SO
# base
# solve
# Sci-Fi
# women.
# different.
# charge
# poor,
# Be
# ball
# 25
# J.
# First,
# routine
# Greek
# past,
# contact
# Crawford
# aged
# cruel
# myself,
# frightening
# tribute
# handful
# rules
# dislike
# structure
# shot.
# mature
# guys,
# horrific
# existence
# why.
# fictional
# 13
# 70s
# amateurish
# offensive
# driver
# tied
# Oliver
# replaced
# annoying.
# plastic
# levels
# equal
# Linda
# Such
# gain
# wit
# Ron
# arms
# indie
# bus
# fans,
# />Anyway,
# once,
# entry
# metal
# either,
# embarrassed
# \the
# raw
# saves
# game,
# Ted
# grows
# paint
# enemy
# title,
# examples
# father.
# eyes.
# rubbish
# mentally
# Things
# eight
# talent.
# Sure
# town.
# warning
# frankly
# wanna
# non
# Along
# jumps
# stories,
# frequently
# par
# cynical
# position
# delivery
# foot
# underground
# eyes,
# riding
# funnier
# asleep
# jokes,
# drink
# REALLY
# refuses
# suffered
# express
# paced
# Jesus
# choices
# interest.
# clips
# minds
# concerns
# locked
# far,
# convey
# while,
# etc
# Rose
# birth
# fan.
# go,
# Definitely
# town,
# degree
# views
# sleazy
# Blue
# Leslie
# husband,
# ashamed
# identify
# stealing
# expression
# Morgan
# sends
# miles
# masterpiece.
# troubled
# future.
# Pretty
# lesser
# truck
# Look
# thriller,
# belongs
# slight
# stood
# allowing
# Come
# classic,
# remaining
# weapons
# entertain
# Korean
# challenge
# camera.
# act.
# appearing
# ill
# abuse
# Back
# young,
# figures
# established
# stars,
# play.
# dead.
# sucked
# idea.
# Barry
# connected
# status
# sure,
# quest
# Someone
# Tommy
# reasonably
# good.<br
# attacks
# sleeping
# Yes
# infamous
# pleasantly
# ways,
# dragged
# honest,
# hole
# dialog,
# parts,
# seriously,
# Keaton
# shows.
# perfect.
# continuity
# France
# *
# balance
# wind
# Lynch
# violence.
# (that
# teach
# movie:
# baseball
# editing,
# budget.
# Meanwhile,
# warn
# movement
# own,
# Brad
# Channel
# says,
# worthwhile
# advantage
# accepted
# opened
# Chaplin
# 2,
# hundreds
# narration
# criticism
# associated
# selling
# nudity,
# they'd
# uncomfortable
# flow
# escapes
# overcome
# laughter
# festival
# />By
# idiot
# person,
# host
# market
# Bollywood
# surprises
# intellectual
# obnoxious
# speed
# true,
# description
# appreciated
# woman's
# millions
# broke
# homage
# bitter
# Seagal
# fans.
# Why?
# countless
# matter.
# Chan
# (John
# wins
# unfortunately,
# anyway,
# evening
# case.
# subsequent
# General
# May
# Sunday
# thought,
# usual,
# quality.
# pointed
# rolling
# instantly
# dogs
# moment,
# 10."
# rival
# Michelle
# oil
# Rachel
# successfully
# does,
# rid
# talked
# striking
# Probably
# Alice
# sets,
# packed
# guessing
# />First
# breath
# marvelous
# kidnapped
# concert
# lacked
# Europe
# circumstances
# physically
# upset
# Powell
# titles
# name,
# Island
# task
# develops
# extras
# suggests
# acted,
# Festival
# albeit
# scenario
# whatsoever.
# path
# storyline,
# beach
# right?
# forgettable
# watches
# Marie
# Finally,
# Bette
# ice
# YOU
# push
# specific
# realise
# Green
# subtitles
# expert
# star,
# guest
# works.
# MGM
# surface
# Sadly,
# Harris
# theaters
# pregnant
# (except
# resembles
# dealt
# repeat
# sophisticated
# national
# prevent
# ensemble
# spoiled
# (no
# Flynn
# (this
# flesh
# revealing
# anyway
# unconvincing
# predictable.
# mass
# yeah,
# caring
# thousand
# per
# past.
# causing
# opinion.
# Burt
# DO
# service
# sword
# strangely
# men.
# welcome
# chasing
# Maria
# reality,
# skill
# dropped
# sexually
# providing
# />I've
# happily
# chief
# Show
# poignant
# daily
# idea,
# sisters
# hero,
# Give
# />They
# directorial
# essential
# Girl
# fine,
# mother.
# Halloween
# attracted
# basis
# fish
# Army
# shut
# states
# 10,
# sucks
# answers
# expressions
# Lucy
# brave
# comical
# entertained
# Boy
# Blair
# lawyer
# danger
# inspiration
# shines
# ironic
# returning
# corrupt
# scale
# spoken
# idiotic
# themselves,
# B-movie
# child,
# sequel,
# fifteen
# werewolf
# murderer
# dead,
# sex.
# naturally
# Actually,
# attention.
# Here,
# Roy
# colorful
# old.
# bound
# fame
# screenwriter
# time."
# Blood
# Out
# torn
# hopefully
# quote
# sad,
# lying
# Wilson
# I,
# threw
# decades
# Johnson
# object
# Soviet
# flight
# thirty
# substance
# 1st
# rule
# laughs.
# competent
# Plus,
# stylish
# California
# Golden
# what?
# timing
# there.<br
# too.<br
# 1.
# Yeah,
# alone.
# crude
# same.
# forgive
# laid
# commit
# fool
# authentic
# disappointment.
# National
# sheriff
# flaw
# dollar
# king
# terrorist
# career,
# flawed
# have.
# racist
# Next
# ridiculously
# hoped
# ones.
# film;
# reality.
# kicks
# carefully
# trick
# real-life
# everything.
# parts.
# uninteresting
# sings
# States
# ranks
# Clark
# perfect,
# politics
# matter,
# stated
# beautiful.
# tour
# cell
# Poor
# mistakes
# table
# load
# jumping
# obscure
# fabulous
# returned
# checking
# viewer.
# Street
# thriller.
# court
# tons
# blows
# dude
# park
# wondered
# larger
# extended
# anymore.
# adapted
# Cary
# Over
# Roberts
# expensive
# gripping
# romance,
# stuff,
# importance
# repeatedly
# whoever
# portrait
# Really
# crafted
# Almost
# neat
# achieved
# Jonathan
# nice,
# unintentionally
# movies.<br
# accents
# arrive
# person.
# while.
# surrounded
# exercise
# angles
# regard
# pretend
# builds
# fourth
# tune
# better.<br
# reaches
# Had
# blood,
# briefly
# passes
# enormous
# cared
# primary
# interaction
# drunken
# Special
# Award
# work.<br
# demands
# funny.<br
# hire
# Living
# shape
# name.
# solely
# explaining
# killer.
# ratings
# Space
# (from
# conclusion,
# soundtrack,
# atmosphere,
# girls,
# imaginative
# witch
# politically
# sister,
# credibility
# everyone,
# winner
# think.
# also,
# involved.
# influenced
# daughter.
# maintain
# scripts
# prisoners
# WWII
# relevant
# pool
# affected
# intensity
# encounters
# annoying,
# Emily
# burn
# Family
# laughs,
# cool.
# Would
# age,
# worried
# aging
# golden
# response
# Men
# Stanley
# Whether
# R
# attached
# Lots
# melodramatic
# complain
# shots,
# frustrated
# novels
# staying
# reasons.
# covers
# Ian
# innocence
# profound
# van
# Terry
# personalities
# currently
# Final
# undoubtedly
# alone,
# television.
# release.
# mountain
# resemblance
# tear
# NEVER
# fairy
# release,
# attraction
# appearances
# deliberately
# burning
# many,
# continued
# harder
# wonderful,
# enjoyment
# amounts
# tree
# agreed
# Jon
# logical
# Betty
# queen
# 45
# Stan
# farm
# disbelief
# ON
# reached
# characters'
# hardcore
# entertainment,
# settings
# insulting
# occur
# help.
# unforgettable
# french
# signs
# characters.<br
# Besides
# sub
# hilariously
# stronger
# writer,
# Norman
# Lou
# problems,
# Tarzan
# development,
# 2nd
# Dunne
# up.<br
# hates
# killer,
# newspaper
# Here's
# era.
# ought
# Plus
# art,
# theory
# taught
# intention
# talent,
# wonderful.
# Khan
# clues
# lessons
# comfortable
# murderous
# wake
# benefit
# storyline.
# Music
# developing
# Nancy
# />Overall
# charismatic
# start.
# weight
# facing
# discuss
# stupidity
# girl's
# patient
# root
# afford
# highlights
# laughable.
# St.
# bare
# really.
# Hitler
# grab
# poor.
# happen,
# beginning.
# backdrop
# quality,
# stranger
# stretch
# upper
# evident
# Could
# Cameron
# classical
# 10/10
# theater.
# psycho
# 80
# Aside
# killed.
# introduces
# Superman
# scream
# sits
# productions
# Irene
# Eastwood
# relies
# elaborate
# (i.e.
# beneath
# 14
# watch.<br
# problems.
# Southern
# environment
# aside,
# suits
# investigation
# heroic
# cheap,
# succeed
# strikes
# blatant
# awards
# Unless
# movie)
# pays
# shortly
# bit,
# captain
# occurs
# restaurant
# Franco
# fond
# partly
# irony
# sentimental
# crap,
# unpleasant
# sequences,
# amazing,
# Ruth
# bag
# ad
# Claire
# press
# sticks
# ignored
# hunting
# episodes,
# investigate
# Quite
# notion
# era,
# uninspired
# shorts
# kicked
# explicit
# always,
# HBO
# brutally
# dull.
# dedicated
# planned
# performers
# effect.
# dozens
# villain,
# atrocious
# everyone's
# Kurt
# minimal
# (such
# detailed
# Acting
# accompanied
# movie...
# bit.
# generic
# Imagine
# ridiculous,
# whatsoever
# gag
# parents,
# describes
# had.
# Kennedy
# broad
# anyone.
# liking
# fitting
# belong
# song,
# reactions
# Fonda
# universe
# justify
# poster
# headed
# have,
# franchise
# stunts
# removed
# consistently
# horrors
# Lane
# video,
# Alfred
# pleased
# />An
# cases
# exposed
# Miller
# tad
# motivation
# survivors
# joke.
# Think
# darker
# Indeed,
# absence
# worst.
# Zombie
# battles
# :)
# misses
# wrapped
# start,
# remarkably
# different,
# arm
# charisma
# loads
# Based
# recorded
# 100%
# Power
# comedian
# short.
# next.
# />Director
# />Now,
# shower
# fancy
# all-time
# doomed
# />Why
# nightmare
# brand
# yourself.
# highest
# effort.
# Lugosi
# 3.
# portion
# proceeds
# underlying
# 60's
# because,
# technically
# Soon
# friend.
# Diane
# look,
# material,
# along.
# period.
# Seeing
# smaller
# Secret
# conventional
# Alien
# consequences
# Willis
# notably
# mansion
# holiday
# chases
# ruthless
# Hope
# crack
# Through
# Check
# Second
# Man,
# catches
# titled
# revelation
# distant
# afternoon
# documentary,
# OK.
# />Also
# seeks
# />Also,
# tie
# weekend
# pretending
# Wild
# psychotic
# guts
# antics
# guys.
# internet
# represent
# regardless
# resulting
# silver
# crucial
# LOVE
# Later
# possessed
# official
# \A
# trio
# Indians
# superbly
# killed,
# Whatever
# />He
# acceptable
# hooked
# eccentric
# shadow
# Carol
# admit,
# evil,
# one."
# blowing
# suspense.
# dubbing
# illegal
# writer/director
# chances
# pace,
# it...
# \"You
# nearby
# LA
# soundtrack.
# Todd
# messages
# guilt
# still,
# individuals
# southern
# smoking
# crimes
# why,
# intent
# earned
# rushed
# health
# />Just
# spooky
# truth,
# vacation
# raped
# depicts
# country,
# dynamic
# videos
# glass
# 16
# trial
# spin
# Cold
# seeing.
# (by
# screams
# contained
# alongside
# vampires
# interest,
# knock
# experiment
# Right
# considerable
# incident
# hours,
# Hitchcock's
# die.
# category
# Hollywood's
# rank
# you.<br
# movie;
# bond
# tends
# goal
# cheese
# MST3K
# meaningless
# cousin
# someone's
# conversations
# swear
# discussion
# burned
# gentle
# text
# miserable
# trash.
# Francis
# Obviously
# department
# officers
# gift
# intrigued
# note,
# shy
# legs
# prostitute
# Hardy
# agrees
# treasure
# conspiracy
# repetitive
# editor
# Germans
# teaching
# mirror
# daring
# philosophical
# suck
# Comedy
# disturbed
# displayed
# composed
# castle
# ideal
# destruction
# offended
# Man\"
# card
# We're
# copies
# particular,
# staring
# trained
# />Most
# Arnold
# hunt
# suited
# curiosity
# business.
# treats
# show.<br
# recognized
# course.
# winds
# differences
# Either
# studios
# oddly
# president
# climactic
# pack
# cameos
# beer
# format
# (I'm
# comparing
# documentary.
# thrillers
# suspects
# murder.
# marks
# overlooked
# instead,
# Moon
# workers
# coach
# masterpiece,
# 18
# />How
# loyal
# sitcom
# Duke
# racism
# relative
# bears
# success.
# stereotype
# nurse
# Angela
# improved
# ghosts
# Basically
# score.
# finger
# hat
# You're
# Tarantino
# knife
# ourselves
# Carl
# rely
# Connery
# spare
# killings
# jokes.
# from.
# agents
# realistic.
# surprise,
# Jeremy
# strong,
# groups
# Stanwyck
# view.
# doubt,
# Lucas
# everywhere
# jealous
# animation,
# Dirty
# costumes,
# parallel
# strip
# centers
# Catholic
# involvement
# manager
# wished
# Drew
# seen.<br
# unbelievable.
# yet.
# photographed
# toy
# toilet
# Godzilla
# decisions
# show's
# reads
# Nevertheless,
# exchange
# vaguely
# special.
# menacing
# staff
# Hell
# kung
# L.
# 50's
# (an
# joined
# grim
# Laurel
# 1950s
# guide
# result,
# girlfriend,
# audio
# meat
# argument
# documentaries
# staged
# closest
# childish
# clumsy
# terrifying
# remained
# Rick
# 2)
# room.
# forever.
# realistic,
# intentions
# bucks
# songs,
# intelligent,
# receives
# Welles
# equivalent
# hype
# commented
# writing.
# visiting
# slightest
# Season
# believable,
# stiff
# lay
# complaint
# \
# Except
# similarities
# tales
# turkey
# sun
# Africa
# dramas
# maker
# thick
# Thanks
# ANY
# York,
# Sally
# mild
# fought
# Father
# Top
# Apart
# blew
# sure.
# neighborhood
# Britain
# guy's
# creation
# armed
# Ghost
# />No
# Gothic
# honor
# weak,
# wicked
# side.
# Owen
# new,
# secrets
# vague
# Roman
# />Maybe
# river
# hysterical
# joins
# China
# truth.
# twin
# Errol
# situation,
# trite
# nine
# threatening
# dialogs
# painting
# spell
# occurred
# Civil
# nervous
# sweet,
# were,
# unintentional
# superb.
# world.<br
# Chicago
# theater,
# pet
# viewer,
# chased
# laughably
# link
# enjoy.
# society,
# Wallace
# Wes
# indeed,
# grave
# hints
# Grace
# premise,
# fine.
# lowest
# kid.
# heist
# Excellent
# arrested
# focusing
# works,
# ex
# pushing
# ruins
# Neither
# fears
# development.
# hatred
# con
# wet
# transformation
# liberal
# condition
# drops
# fired
# Hills
# vivid
# International
# instance
# CIA
# view,
# spread
# 60
# be.<br
# we'll
# events,
# orders
# whole,
# Actually
# warned
# suitable
# smoke
# population
# Mad
# />Unfortunately,
# involved,
# reflect
# everything,
# virus
# Throughout
# exotic
# 1/2
# Way
# impress
# Bogart
# capturing
# sacrifice
# persona
# spoilers
# care.
# Mitchell
# Jake
# Saw
# disappointing.
# overall,
# episodes.
# homosexual
# kiss
# anyone,
# Native
# Pitt
# \"What
# weapon
# it:
# combat
# brilliance
# sexuality
# Princess
# landscape
# failing
# Nice
# noble
# juvenile
# specifically
# presumably
# Sidney
# aka
# />*
# Angeles
# corporate
# Sinatra
# Ellen
# assigned
# far.
# coherent
# fortune
# Films
# ****"
# />Title
# at,
# showcase
# painted
# directed,
# also.
# Warren
# 3rd
# sidekick
# Witch
# Force
# settle
# ONE
# Penn
# beings
# slice
# replace
# suggested
# wishing
# projects
# raises
# superficial
# manner.
# Up
# Craig
# hence
# scores
# Karloff
# require
# web
# valuable
# Better
# Grand
# floating
# chance,
# vs
# cleverly
# exceptionally
# improve
# trilogy
# demonstrates
# Pacino
# addition,
# superb,
# emphasis
# happens,
# rubber
# advise
# favorites
# Dutch
# engage
# legal
# spoke
# waited
# car.
# outcome
# inane
# Forget
# cried
# depicting
# ones,
# weakest
# Sandra
# blah
# broadcast
# lead,
# can.
# Home
# setting,
# Given
# (Brazil):
# Hoffman
# Nobody
# Worst
# ticket
# fu
# exaggerated
# lame.
# Harrison
# alternative
# aid
# Art
# drawing
# atmosphere.
# month
# plot.<br
# 90's
# 24
# grandfather
# herself.
# abilities
# errors
# disc
# Wow,
# horrid
# viewers.
# Dr
# Derek
# Dorothy
# symbolism
# die,
# severely
# Real
# inventive
# Absolutely
# Killer
# husband.
# dire
# fantastic.
# bleak
# it;
# Lake
# characterization
# it'll
# claimed
# wore
# freak
# chair
# hearts
# dialog.
# rating.
# Worth
# endearing
# Harvey
# city.
# cheesy,
# Turkish
# hero.
# slap
# convoluted
# screen.<br
# />Yes,
# candy
# perfectly.
# alternate
# arrival
# loosely
# value.
# Margaret
# frequent
# narrator
# sucks.
# realizing
# instant
# innovative
# Spielberg
# helicopter
# cabin
# scenes.<br
# daughters
# defeat
# splendid
# swimming
# couples
# EVER
# darkness
# teaches
# Mario
# switch
# user
# silly.
# nose
# cup
# discovering
# Mystery
# Certainly
# Seriously,
# Shirley
# Emma
# notes
# spoiler
# genius.
# surprise.
# coffee
# cameras
# suspicious
# possible,
# defend
# />Finally,
# AT
# Pat
# sloppy
# league
# wound
# useful
# opinions
# directs
# not.<br
# Italy
# recognition
# constructed
# installment
# eager
# breathtaking
# screenplay,
# thumbs
# flash
# implausible
# chooses
# character.<br
# wife's
# Vampire
# react
# duty
# (see
# handed
# =
# survived
# survival
# credits.
# Jesse
# shine
# review,
# problem,
# expected.
# city,
# endure
# other's
# one-liners
# (she
# body,
# BAD
# inappropriate
# isn't.
# critic
# ups
# thrill
# Ice
# nevertheless
# advance
# Campbell
# satisfy
# passionate
# overwhelming
# flat,
# craft
# shake
# explosions
# future,
# Hall
# shares
# popcorn
# NOTHING
# set,
# severe
# challenging
# affect
# X
# stellar
# Lawrence
# wildly
# brains
# Hill
# Several
# scene.<br
# Cage
# general,
# Nazis
# terrorists
# morality
# props
# medium
# gifted
# futuristic
# earlier,
# walls
# i.e.
# Beverly
# B.
# depressed
# Carter
# timeless
# Bernard
# recommended.
# casual
# areas
# Considering
# time!
# competition
# guarantee
# surviving
# Judy
# introduce
# Maggie
# colour
# grasp
# chain
# simplistic
# scripted
# pathetic.
# adequate
# recording
# purchase
# camera-work
# 19th
# theme,
# worthless
# wandering
# writes
# segments
# secretly
# horrendous
# 1)
# moving,
# subjects
# (they
# secondary
# inability
# combine
# project.
# wannabe
# Rather
# miscast
# kicking
# guests
# invited
# Hunter
# lasted
# trashy
# versus
# guessed
# June
# drugs,
# bullets
# (also
# Edgar
# sending
# odds
# Claude
# people.<br
# hunter
# masterful
# fooled
# wave
# wacky
# scheme
# in.<br
# (Michael
# incoherent
# importantly,
# montage
# Years
# loser
# homeless
# compelled
# inspiring
# estate
# words.
# released.
# Le
# bullet
# ties
# forms
# neck
# curse
# cute,
# catching
# messed
# flies
# Caine
# dialogues
# myself.
# word,
# leg
# />Perhaps
# witnessed
# Walker
# sequences.
# closed
# visits
# Colin
# Damme
# America's
# disjointed
# slick
# REAL
# referred
# set.
# \"I'm
# Ali
# well-known
# (Robert
# nothing,
# Characters
# finish.
# thoughtful
# No.
# review.
# Buster
# hip
# selfish
# store.
# behave
# Navy
# quit
# continually
# MY
# bumbling
# mentioned,
# Sutherland
# notch
# etc.,
# performs
# represented
# flat.
# damage
# ONLY
# hour,
# Has
# Amy
# sadness
# tracking
# distinct
# lands
# 1970s
# />Watch
# him?
# Rogers
# unaware
# cringe
# Set
# contract
# corpse
# nostalgic
# situations.
# persons
# purchased
# confrontation
# enemies
# times.<br
# one!
# Picture
# poverty
# Samuel
# porno
# banned
# Air
# been.
# et
# girls.
# Days
# transition
# reviews,
# Mother
# Can't
# more.<br
# respected
# sons
# cure
# Save
# lame,
# 'the
# />i
# Remember
# breasts
# judging
# gore.
# (what
# Phil
# responsibility
# discovery
# situations,
# philosophy
# evil.
# reaching
# corner
# jerk
# succeeded
# appreciation
# message.
# shared
# trade
# historically
# reflection
# spots
# magazine
# Jeffrey
# sorry,
# photography,
# power.
# inferior
# Hudson
# subtlety
# tracks
# hand.
# merit
# punk
# example.
# clever,
# language,
# promises
# pops
# fascinated
# worn
# Hammer
# forcing
# Diana
# captivating
# period,
# or,
# motives
# civil
# Holly
# herself,
# mystery.
# access
# big,
# heading
# Ever
# thru
# trademark
# background.
# musicals
# Spike
# joke,
# distance
# butt
# method
# understated
# Australia
# preview
# cheating
# explored
# lifted
# marketing
# points,
# intimate
# storm
# explores
# concern
# appalling
# resort
# resemble
# Count
# books,
# along,
# tongue
# principal
# blood.
# pressure
# />Other
# circus
# Bugs
# attitudes
# wholly
# lighting,
# FX
# generous
# white,
# relationship.
# potential.
# glorious
# westerns
# demons
# scenery,
# Hugh
# Murray
# funeral
# Burton
# humble
# owned
# since.
# cinematography.
# tall
# off.<br
# body.
# hideous
# values,
# come.
# report
# prepare
# threatens
# Bush
# sad.
# bridge
# investigating
# fed
# murdering
# Rocky
# 17
# arrogant
# silence
# serving
# humour,
# ingredients
# blond
# was.<br
# Die
# Upon
# representation
# careful
# happiness
# ignorant
# FOR
# relation
# Reynolds
# Meryl
# bottle
# Canada
# disease
# slave
# Outer
# obligatory
# alive.
# subjected
# such,
# goes,
# culture,
# idiots
# destroying
# resolution
# dear
# expect.
# awesome.
# TCM
# .<br
# doll
# wounded
# Kill
# Professor
# />1.
# class,
# Baby
# family's
# borrowed
# feed
# March
# horses
# Charlotte
# smart,
# Alexander
# Bela
# arrived
# adopted
# Dawn
# wreck
# get.
# fighter
# Basically,
# SPOILERS
# crisis
# assumed
# Von
# advertising
# Louise
# Central
# (it's
# rush
# practice
# border
# yourself,
# must-see
# Timothy
# rain
# Streep
# quietly
# exploration
# made-for-TV
# Sheriff
# thankfully
# Olivia
# Inspector
# folk
# stone
# top,
# voice,
# Quaid
# foul
# refused
# demand
# 1950's
# Cat
# either.<br
# madness
# Raymond
# randomly
# shame,
# violent,
# snow
# cave
# Later,
# widely
# calm
# poetic
# fix
# psychic
# souls
# rap
# dating
# cowboy
# etc.<br
# Amanda
# trap
# Doug
# regarded
# fashioned
# downhill
# Randy
# Hopkins
# dimensional
# ninja
# awfully
# endings
# mystery,
# Glenn
# Chaney
# supported
# Boris
# Curtis
# happened,
# duo
# Sherlock
# can,
# hears
# hair,
# buddies
# villain.
# boredom
# bathroom
# jumped
# lab
# plant
# movements
# Sorry
# prominent
# unfolds
# Nicole
# lifestyle
# According
# Hal
# BUT
# nature,
# no.
# credits,
# imagined
# earn
# incompetent
# week.
# Frankenstein
# Keith
# Devil
# Four
# Nelson
# Simply
# DON'T
# similarly
# beast
# von
# devil
# territory
# Jenny
# process.
# (you
# elegant
# checked
# Pink
# Satan
# discussing
# matches
# thinking,
# End
# chapter
# doors
# mentions
# power,
# WAS
# photo
# consistent
# literary
# Make
# Leonard
# would-be
# written.
# deranged
# sentence
# loaded
# basement
# MOVIE
# clown
# precisely
# goodness
# promised
# intrigue
# suspend
# topless
# song.
# team.
# explosion
# were.
# Grade:
# convincing.
# shoes
# standards.
# kid's
# etc.)
# attention,
# enjoyable,
# wakes
# />2.
# accent.
# ---
# thief
# culture.
# Chainsaw
# retired
# invites
# sky
# choreography
# ..
# kitchen
# Seven
# Personally,
# expectations.
# robbery
# scope
# respective
# bold
# formulaic
# controlled
# (yes,
# memorable.
# voice-over
# birthday
# noise
# careers
# entitled
# unsettling
# advanced
# reflects
# additional
# Joel
# trailers
# century.
# Ernest
# creepy,
# ***
# lengthy
# form.
# Jews
# on-screen
# effort,
# Bergman
# firmly
# fatal
# finally,
# message,
# containing
# class.
# gangsters
# nail
# command
# sums
# lyrics
# equipment
# boxing
# />Though
# Freeman
# citizens
# unhappy
# />Its
# half,
# Andrews
# repeating
# stumbled
# MTV
# 0
# Blake
# prisoner
# phrase
# years.<br
# Times
# crush
# neighbor
# sincere
# (just
# frustrating
# jazz
# Orson
# marries
# dignity
# mini
# hopelessly
# **
# smooth
# newly
# don't.
# flaws,
# Bronson
# sound,
# south
# Quentin
# thrills
# commercials
# said.
# excessive
# same,
# Super
# adorable
# models
# mentioning
# refers
# decent,
# disliked
# imagination.
# twins
# Skip
# Classic
# party,
# executive
# popularity
# flawless
# kind.
# refuse
# Virginia
# experimental
# one-dimensional
# seldom
# viewing,
# Norma
# hook
# ordered
# change.
# sounding
# grotesque
# rotten
# 4.
# GREAT
# Return
# piece.
# little,
# presenting
# Scottish
# women's
# boy.
# 60s
# cold,
# weak.
# visible
# English,
# mundane
# Leo
# psychiatrist
# abusive
# Kane
# plight
# knocked
# motivations
# riveting
# points.
# top.
# El
# construction
# sticking
# rates
# revolutionary
# plausible
# Were
# journalist
# strongest
# cinematographer
# grabs
# Victoria
# affection
# transfer
# about.<br
# 8/10
# shirt
# metaphor
# didn't.
# business,
# companion
# husband's
# happening.
# hugely
# lit
# much.<br
# MUST
# with.<br
# encourage
# attacking
# preferred
# heat
# light,
# Gregory
# Ireland
# Burns
# Troma
# thugs
# Austin
# costs.
# lift
# viewer's
# abused
# rendition
# Beyond
# middle-aged
# solution
# alcoholic
# Disney's
# Andre
# Nicholas
# exception.
# pages
# saying,
# performer
# remove
# Ned
# phony
# Detective
# Ross
# actor's
# Waters
# block
# frankly,
# arguably
# destroys
# positively
# believe,
# half.
# nowhere.
# credited
# Ring
# Myers
# (his
# \"My
# tender
# stranded
# series.<br
# Graham
# perhaps,
# global
# BIG
# simple.
# pursuit
# Cinema
# Francisco
# immediate
# Honestly,
# expressed
# darn
# nation
# fantastic,
# immensely
# photographer
# date.
# Ward
# pride
# blockbuster
# Barrymore
# irrelevant
# redeem
# shadows
# feel.
# parties
# conflicts
# Wolf
# Major
# Needless
# boy's
# tale,
# conservative
# nature.
# clothing
# celebrity
# stark
# (both
# Doris
# photos
# will.
# racing
# avoided
# rising
# places,
# Nightmare
# comments,
# what,
# Leigh
# Law
# mistaken
# Carpenter
# less.
# pushes
# team,
# Carrey
# satisfied
# store,
# fair,
# hell.
# sung
# 2\"
# describing
# sharing
# Talk
# bite
# visited
# yelling
# marked
# please,
# measure
# honesty
# Annie
# simultaneously
# hour.
# crazed
# (after
# hell,
# History
# Robinson
# die-hard
# refer
# 2000
# tame
# exciting,
# />That's
# success,
# Allen's
# wrestling
# police,
# Everybody
# list.
# Far
# G.
# perfection
# voice.
# aim
# television,
# going.
# library
# expects
# season.
# primitive
# />Oh,
# farce
# True
# shelf
# />Well
# tension,
# convincingly
# framed
# Manhattan
# Justin
# pants
# lasting
# do?
# provoking
# buildings
# sneak
# disappear
# released,
# rolled
# defined
# choreographed
# definition
# quickly.
# invented
# stress
# Chase
# challenges
# Marc
# methods
# channels
# drove
# widow
# electric
# owns
# creativity
# Clive
# lost.
# Lance
# chaos
# 1,
# Predator
# morally
# troops
# Miike
# eats
# Ten
# Road
# rises
# try.
# shots.
# potential,
# throat
# pointless.
# aspiring
# 4/10
# signed
# objects
# triumph
# screenplay.
# intentionally
# York.
# accident.
# sappy
# guess.
# assassin
# rage
# achievement
# great!
# brother.
# Josh
# Ginger
# parent
# 70
# styles
# dropping
# Until
# Video
# Mitchum
# bonus
# hard,
# invisible
# comedies,
# Eastern
# Antonio
# gem.
# reluctant
# Hindi
# amusing,
# Polish
# Wong
# 1930s
# indeed.
# Usually
# pace.
# levels.
# Beautiful
# whats
# posted
# we'd
# chest
# parents.
# genres
# dancer
# close-ups
# general.
# WAY
# firing
# (when
# stumbles
# />Do
# charming,
# Watson
# complaining
# warmth
# west
# 1970's
# effect,
# rob
# Mason
# subplots
# Try
# insists
# unbearable
# questionable
# Bruno
# form,
# (out
# combines
# nomination
# water,
# nowadays
# undercover
# appropriately
# relationship,
# conclusion.
# Patricia
# Lee's
# soon.
# Vegas
# tribe
# friend's
# Conan
# website
# Finally
# composer
# (And
# authority
# household
# –
# campaign
# crashes
# Sex
# Rita
# Cinderella
# Latin
# cartoon.
# pitch
# historic
# Angel
# wrap
# crime,
# compete
# NYC
# exploring
# flicks.
# transformed
# editing.
# underwater
# Eugene
# adaptations
# tempted
# witnesses
# Crystal
# dysfunctional
# anyone's
# Price
# Believe
# disaster.
# you!
# distracting
# monkey
# Theater
# keen
# should've
# />I'd
# confront
# understandable
# stretched
# disappeared
# Truly
# glowing
# horrifying
# inexplicably
# fifty
# Bay
# Battle
# establish
# />\"The
# Stuart
# ships
# deserted
# fascination
# astonishing
# 3,
# debate
# mistake.
# Che
# Wonderful
# Smith,
# no-one
# pot
# handles
# stumble
# dreary
# Mom
# eaten
# minutes.<br
# Matthau
# screwball
# leads,
# namely
# crime.
# Sadly
# nonetheless
# actually,
# voted
# progress
# claiming
# alright
# tale.
# educational
# weakness
# Scorsese
# guitar
# L.A.
# close.
# illogical
# died.
# shame.
# Union
# ...
# Disappointingly,
# *think*
# bloodlust
# longer...
# automatic,
# Dancy,
# humidity
# coastline,
# solos,
# Begged
# Leave,
# Jouvet's
# Iturbi's
# store\"
# budge.
# />Norman
# commiserate
# roughie
# clichée
# Graver
# didactic.
# notebooks
# Bull\"
# bucked
# Unknowingly
# story'.
# Seed's
# faring
# (special
# (Cannibal
# over-stretched
# Cassavettes,
# re-thinking
# preferred.
# Identical
# place?"
# drier
# wandering.
# personality:
# joyous.
# wrong...I
# moms.
# (True
# ONCE,
# anyways).
# Augustine
# BONNIE
# CLYDE,
# womb,
# precision.<br
# depreciating
# falsification
# teaser,
# Conduce
# thrillingly
# link\"
# spoilers).
# text?
# lake).
# Alba.<br
# hero...
# Encino
# simpsons
# cheap?
# ludicrous!
# generous!
# 'Demons
# 2004?
# diversions,
# minutes!"
# \before
# globalized
# Cavalry,
# brothers\"
# Ma.
# Nabokov
# spiritless
# barrio
# Diddy
# Flux\"
# Darko\"
# audiovisual
# Loyalist
# Brigante
# protesters.
# non-anamorphic
# DD5.1
# inspected
# Kurasowa
# Randall.
# Hossein
# miscarriage,
# Henri's
# Rhythm'
# metal\"
# favor."
# Cronkite
# Patil
# Tachiguishi
# Cathrine
# Amrapurkar
# Ruling
# reverberate
# steak,
# adolescents.
# Time.<br
# screamed.
# finalize
# Caetano
# Laurie's
# nerve-racking
# Nihalani's
# cooked,
# 10-minute
# boldest
# Mermaid\"
# />Davies
# '10
# glitters
# re-established
# song/dance
# cold-eyed
# resentment.
# (vampire
# container.
# Cambodia.<br
# datedness
# condo,
# Sherman.
# Concorde.
# shortage,
# H's
# SYMPATHY
# \"monster
# championships
# grenades.
# (Francesco
# bloodbath,
# forever.\"
# saved!
# bended
# process).
# \"wow\"
# fourth-rate
# molested,
# moderator
# WAR,
# folder
# antithetical
# disruptions
# Comcast
# defraud
# killers;
# \"effort\"
# speed)
# plumbing,
# deconstruction.
# \"Hamlet\",
# {which
# odd)
# home'
# campesinos,
# Insult
# Abuse
# Appearance
# Janel
# ON!!!
# Tyler),
# blotting
# faces)
# Segals
# naturalist
# both:
# Ah!
# mini-series)
# \"Offside\"
# stick;
# Fleet's
# blonds,
# place?)
# weird."
# supplemental
# ripping,
# man-hungry
# chemistry;
# politically.
# tormentor.
# be:<br
# Reems
# 'horrible'
# Street.\"
# Cagney.<br
# spires
# \yeah,
# (Let
# record\"
# promulgated
# computing
# Shue),
# naiveté.
# about\"
# hella
# noms
# Reiser)
# pectoral
# cameo?
# workaholic,
# Tilly.
# recollects
# Kleinman
# Teru
# Run\".
# She-Ra,
# non-realistic
# find."
# />Reign
# DUMBEST
# Autobiography
# Sevier's
# because)
# \42nd
# Physically,
# rainstorm.
# cast\"
# lemons
# Ledger)
# (Heath
# deserted.
# looker.
# Curry.
# apiece.
# AGES
# ploughing
# Cheerleaders
# Parody
# Dietrich)
# SNUFF
# Within\",
# Alice\",
# fowl
# Amidala
# anywhere)
# turning,
# outstanding."
# pixelated
# humorlessness
# doubt).
# \Indian
# Pabst,
# Romano's
# Lying
# grinded
# willy
# Karzis
# prophesied
# \"rescue\"
# Short.<br
# dialog:
# Newcombe's
# 'Every
# feint
# nose.<br
# 'deep
# Indians;
# him.)
# Raoul\"
# Craig),
# too
# Wives\",
# jotted
# old-timers
# BABIES
# firsts
# infants.
# tempted,
# 17-18
# Fugitive.
# Hollywood.)
# channels."
# Grinders
# philosophies.
# spoiler.)
# skiing,
# streamlined,
# lack,
# ugliest,
# \"Ray
# retards.
# Cards
# Spy,
# (1989).
# setter
# acidity
# bestowing
# mind\".
# passages.
# fare!
# 'Dracula'
# self-delusion
# chased,
# it's...
# super-hot
# \"creepy
# underwhelmed.
# Miraculously,
# Kudos.
# hopelessness,
# ...its
# Massachusetts,
# eighteen,
# is...well
# />Broken
# Morbius'
# pre-production,
# \"Wake
# automobile.
# racecar
# />Benny
# \"Cover
# McManus
# myself?
# chins
# Drago.
# revelry
# Pumpkinhead.
# movies.This
# unbalanced,
# condescendingly
# Templar,
# \"Psycho,\"
# Barbies
# carefully:
# blood-thirsty,
# cheerful.
# critiques.<br
# again).<br
# Kill,\"
# faces?
# Intent
# Arthur.<br
# ga-ga
# catalogs
# boat's
# visage.
# oaf.
# voices?
# Ugh."
# love',
# portmanteau
# Placid.
# Quirky,
# weird-looking
# LB
# mystery."
# movies...and
# nous
# 14/15
# sexualised
# fencer
# design!
# \"male
# Kathleen,
# make!
# Frasier.
# receptacle
# Kathleen.
# \"us
# Damned.
# deflowered
# inconsistencies.<br
# Lily?\"
# feeding,
# Clair's
# forced;
# closet.<br
# \"scares\"
# \"weird
# out-acts
# mallet
# Hallorann
# Prague'
# 1913,
# (past
# Puss
# President?
# copy's
# Luke\"
# \"Gamera
# screen-play
# \"guilty
# sites.<br
# male.<br
# \"married
# return)
# horror/cult
# cogs
# gigantically
# win."
# readings.
# (Leon
# \"father\"
# Umeki
# *no
# comforting,
# Blue\",
# delight."
# \documentary.\"
# \"isn't
# pap,
# stubborn.
# characterless
# web.<br
# nightgown
# Witney
# tunics
# \"Auntie
# self-censorship
# Pack,
# Tale\",
# environments.<br
# built-up
# CGIs
# pleasure\"
# reduced,
# dunderheads
# \"Fahrenheit
# fiance.
# slumber.
# Eileen,
# Land\",
# dignitaries
# inelegant
# 70s/early
# Barn
# Jenna,
# Bhandarkar's
# encroach
# Sabu's
# Selden
# writer/director/actor
# Banks'
# 1861
# Jafar.
# Duval,
# \"DIL
# castigate
# pre-schooler
# 2054
# slouch,
# venues,
# valleys,
# \was
# rentals,
# nobodies.
# oracle
# bombings.
# Sabu,
# (Fast
# Limbaugh
# \Snakes
# non-glamorous
# mattered.<br
# Applegate.
# dowdy,
# KKK,
# awful!!
# Anders,
# Lawton
# MOR
# \"flying
# (Spoilers)
# Women.\"
# Rey)
# Rozsa's
# \1
# highly-rated
# defeatist
# pupils.
# predictive
# survivors.<br
# mindset.<br
# TRIPLE
# autos
# Frenzy
# \Shrek\"
# being."
# one-dimensionality
# grasshoppers.
# Napoli
# Antz,
# Antz
# horrific!
# deferred
# fixating
# Not!
# APARTMENT
# flaying
# float.
# tripod.
# supernatural;
# \Lone
# (Elias
# eyes'
# screen).<br
# Landmark
# Saturn,
# Akane
# Pendleton.
# (naturally).
# Jenks
# \"that\"
# Lettieri
# flunks
# stains.
# Intentions.
# fingers.<br
# Cramer)
# Entebbe
# dyes
# Segonzac
# smash.
# deep-sea
# doorknob
# value)
# seeing!"
# always<br
# cheap."
# $50,000.00
# impeccable.<br
# new."
# Conquest
# thin-skinned
# Clark\"
# monitor.
# Grey\"
# credentials?
# phenomena.
# Updated
# $7.00
# davis
# Ferengi
# Tension\",
# remainders
# pick-axe
# wallets
# \"talking\"
# harris
# has-been,
# seems),
# original).<br
# Street',
# Quinten
# Days\".
# Lilo
# \foreign\"
# Riddled
# Unpleasant
# crow.
# Accuracy
# could)
# caramel
# OUGHT
# supervisor.
# '4',
# Salon
# early-to-mid
# short-cut
# brandishes
# sea\"
# commandos,
# \"mature\"
# Sheffer,
# evil'
# Cleary
# *or*
# (consider
# XXX,
# Merrill's
# Calson
# venoms
# 'Follow
# elan
# Sandwiched
# />Tracy
# Twenties,
# remaster
# ink.
# Lang)
# stammering,
# **May
# money..
# Marv,
# Saito
# Lois.
# Spoorloos
# Tremaine,
# SuperFriends
# Melchior
# spider's
# bras.
# feeling;
# Lake'
# Loyd
# 'typical
# denizen
# Family\".
# 'masterpiece'
# Treat\"
# 'Ed
# him
# Sammi's
# driver)
# laugh...<br
# intersperses
# fraud.<br
# familiarized
# torture."
# objections.
# seated.
# Motor
# Blanc.
# Robins
# (some)
# grills
# rapport.
# implode.
# thorough.
# apathetic.
# over-hype
# scouts,
# bridges.
# unplayable
# minus,
# guitar?
# druggies
# investment.<br
# \"Seven\"
# film!\"
# just.<br
# promise:
# Gigolo
# phenomenons
# Valkyries
# \accidentally\"
# ignorant.<br
# level).
# Tristram
# (90%
# Crucial
# \"Higher
# Dames
# 1994's
# is--the
# teacher\"
# stimuli
# summary.<br
# loners,
# bouncy,
# Music's
# Myron,
# insecurity.
# Soderburgh
# EVIL.
# Marti
# face),
# epics.<br
# films,\"
# Grave\",
# TV-like
# />Mix
# \visions\"
# Magoo.
# sweats,
# Pray,
# Sahan
# USING
# bad.I
# Togan
# counsels
# \those
# his)
# whimper.
# Eamonn
# kickin'
# over-long,
# Junkermann
# meting
# MUSICAL
# hankie
# Away'.
# adolescence.<br
# lecher
# O'Leary
# \"independent\"
# intoxicating.
# possessed.<br
# brawls.
# beads,
# chain.<br
# Willie\"
# JIM
# trashiest
# gas?
# GENTLEMAN
# \"popular\"
# vulnerable.<br
# to!!
# dumpsters
# />Couple
# Kazuhiro
# West:
# women.\"
# Abortion
# Manufacturing
# sated
# But...<br
# applauded,
# Go!
# 'Spirited
# Nablus.
# manipulations.
# top-ten
# />MAJOR
# McGoohan,
# her!\"
# minors.
# Tarkovsky.
# obtuse,
# intersect,
# levels."
# staleness
# well-executed,
# \"grown
# matters:
# Ragland,
# Rhino,
# cutter.
# Begley,
# probation,
# payers
# World'.
# scraps,
# enthralled,
# Busey)
# romance\"
# used).
# shelters,
# \Law
# princes,
# Violence.
# rough-and-tumble
# prime."
# Screening
# />Typically
# \Sin
# O'Brien)
# (Winona
# rumor.
# (close
# Holm.
# Midwest,
# chalkboard,
# 4,\"
# stupidity?
# fates.<br
# brilliant).
# down,\"
# whist
# crowd?
# scythe.
# BRIGHAM
# Vallée
# movie--it's
# fugue
# breakthrough,
# Italian?
# D'Onofrio,
# ten"
# Trekkies,
# prayers,
# Natural,
# involved).
# on-target
# Angie's
# apology,
# really;
# four-minute
# facilities,
# SENTINEL
# heart-attack
# Bundy,
# hung,
# Poetry
# blown.
# bookstores.
# hunchback,
# Vampires:
# />*END
# enticing.
# legend...
# Himalayas,
# crisper
# risk!"
# feels.<br
# titles:
# \"M*A*S*H\"
# elevation
# contrasts,
# Tan,
# tempest
# Maupin
# Muller's
# DRACULA
# out-right
# />There`s
# spookiest
# glued.
# C&C
# Nerds,
# \man\"
# singing?
# BF
# poetry.<br
# Batmans
# Radar
# Dad\"
# />\"Black
# Shinobi
# \"...and
# \"comedies\"
# Spielberg)
# bubble,
# resell
# movie...even
# Artic
# disgusting;
# streetwalker
# cheaply-made
# />Michel
# Marjorie's
# economy.<br
# rape),
# Edgar's
# unfathomable.
# Dame.
# holes?
# captivatingly
# what-so-ever,
# Fitzpatrick
# Thanks!"
# crucial.
# Dickey,
# Boorman.
# Expected
# coddling
# footing,
# 'David
# known?
# \Public
# />Gandhi
# resuscitation
# Mohandas
# misleads
# Kasturba
# jokes),
# Alberta
# miner's
# fines
# `Why
# \chosen\"
# Lugia
# Sundays.
# twister
# £1.99
# number)
# XV's
# filmmakers).
# Fabulous,
# wo
# dork,
# />*possible
# Spencer.
# wonderful)
# Man,'
# F/X.
# George:
# Fraser.
# painful;
# gray-haired
# scribblings
# Tippi
# battery,
# \"quality\"
# thoughtfulness.
# 'Ring'
# smart;
# righteous.
# Universities
# breech
# Eowyn
# mispronunciation
# solution:
# War.\"
# scripts."
# (Rip
# unneeded.
# \"Raptor\"
# Raptors
# />`The
# (horrible
# move),
# glamorise
# \Match
# heart).
# band)
# HIGH,
# TAKES
# Do'
# alcohol.<br
# Judels
# killer!
# normative
# kick!
# noir:
# Cullen
# \"Shaggy
# DESTINY
# Railly,
# disbanded
# bohemians
# \"Boom\"
# (films
# Addy
# restaurant.<br
# SING,
# (Paddy
# Fur
# Lance.
# implores
# Zealand's
# Koch,
# 'snuff
# Rock)
# marshes
# \"Howl's
# Sucks.
# track?
# scoping
# hope).
# Majid
# \erotic\"
# PR,
# whorehouse.
# Menville
# Hawks.
# owning,
# Ghandi
# Anglophile
# seconds?
# flawless!
# Beck's
# much-heralded
# float,
# revulsion.
# \"Butch
# Matthau),
# />does
# SM
# she<br
# sharp-tongued
# movie-length
# port,
# Butcher\"
# self-styled
# \wooden\"
# unprecedented,
# pardoned
# sympathizer,
# jaunty,
# \"woman's
# Corri
# Rico.
# nation)
# Katharina
# trouble;
# Twice,\"
# 2006<br
# bye.
# Stones:
# pancakes,
# Emery),
# Annik
# doorways,
# Supes
# \art\".
# character-building
# saw?
# Sleaze
# scar)
# entertainment),
# humors
# (check)
# 1860s
# />Lawrence
# sight)
# libraries.
# SG-1,
# throws.
# genie.
# known."
# />Amidst
# \"Bridge
# 9-11,
# impregnation
# subservience
# Teal'c,
# \"kid
# feature!
# wept.
# learned.<br
# Gabor)
# astonished.
# indigent
# Intimate
# ENEMY,
# Chiklis
# blue-haired
# Brandon)
# thinking)
# Bananas
# Macek
# area)
# (specifically,
# Gentlemen's
# 2009)
# funner
# Girl!
# thinner.
# indestructible.
# creed
# Unseen
# whoever's
# dots,
# roar,
# Lights.
# Ships
# industry?
# voice-over:
# Suits
# libre
# gens
# Ray),
# Sith,
# subscribing
# \"fans\"
# McDonald)
# \"some\"
# Sherwood\"
# shame..."
# maker)
# lab?
# B.B.
# filthy.
# wilted
# Baraka
# sad).
# WHORE
# museum.<br
# ventriloquist's
# self-promotion
# prefect
# commentary)
# voices:
# do.This
# (put
# fantasies.<br
# platitudinous
# innocuous,
# livestock.
# arguments.<br
# relic.
# HELL.
# Ancona
# Beckham's
# Britannia
# wrenched
# armour,
# 2001?
# film.It's
# honest)
# subscription.
# Rea.
# Cocker
# Nineteen
# brutalizing
# 2008)
# Beetle,
# bible-thumping
# precise)
# Gabe's
# Doors\"
# />Sex:
# Fleisher's
# manicure
# -just
# Packards
# bankroll
# Rich's
# Stacie
# Oldest
# sponge.
# Spooner,
# immorality,
# Lady\",
# BOOM.
# underplaying,
# non-fictional
# randomly.<br
# breath?
# ANNIE
# science-fiction.
# seriously:
# Blonder
# Sci-fi,
# destructiveness
# \"Roma
# Pains\"
# minutes.I
# Derailed
# migraines
# Rossellini's
# bulls**t
# \Gee
# owns,
# (roughly
# garbage!!
# Watchable,
# AWFUL!!!
# EMPTY
# Czechoslovakian
# Sleeping,
# double-takes
# \"humour\"
# retina
# Thatcher,
# aides,
# smoothest
# transitioning
# unspectacular.
# those...
# beatific
# gnomes
# pipes.
# Carné's
# Lindon,
# Kubrick.<br
# wide-ranging
# 'em!
# />Ending
# whiners
# Sexy,
# \"Heavy
# Traffic\"
# Rule\",
# Thematically
# R)
# Watanabe)
# priorities.
# cherished.
# MOVIE!!
# 33,
# Male,
# Modesty,
# Monthy
# too.I
# VERTIGO
# \"Judy
# aggression.
# supercharged
# guileless
# Enright
# irreparable
# />Garner
# DeSica
# screen
# mouth-watering
# greenery
# Winnipeg
# impressionable,
# sweet:
# ladies!
# Presley.
# germs,
# Arcand's
# charade.
# all!!!!
# Champions\"
# vampire),
# debate.<br
# Alvarado,
# Her's
# tourist's
# move."
# 1946)
# />\Where
# victim."
# but.<br
# Tully),
# straightens
# Heavy-handed
# Cho,
# sixties/early
# Zombies?
# non-existent)
# bogus.
# />WTF:
# watch"
# tragical
# page)
# this--especially
# thrills."
# powerful...
# considerably.<br
# spookily
# Leisen's
# hand-picked
# ensembles
# -well,
# Good-looking
# proscenium
# fabricated,
# />Polanski
# Hornblower's
# tolerating
# (oops,
# Seek,
# \"monster\".
# \Inside
# \"Holes\"
# desserts,
# Hitchhikers
# thriller.The
# singing).
# parentage
# fantasising
# Ashby's
# ***SLIGHT
# '60s\"
# Grieve
# Vietnam\"
# \"Nemesis
# 1960s?
# 195
# Agreed,
# procreate
# months;
# DDL
# Regan,
# characters's
# COWS
# Huston),
# Connor,
# vividness
# Totoro.
# Pies
# Tasha's
# died.\"
# credit)
# titillated
# Recognizing
# Potter.<br
# credit),
# Ledger's
# Sparrow,
# jumpsuit
# />we
# Franz,
# 'typical'
# \"issues\"
# Figueroa,
# Bowl.
# debt.<br
# frat-boy
# summer\",
# Rogers).
# Lovely\"
# Zima
# Columbo.<br
# break-dancing
# far-reaching
# coos
# />Bing
# script<br
# stupid-funny
# mid-70s
# Tracy.<br
# Later.
# misused.
# Hassett
# Breed,
# Adventure'
# inspection.
# Sci/Fi
# treasure."
# Prophet,
# perceived,
# storywise
# Vince's
# 'EM
# entertainment...
# 3...
# tone-deaf
# Control\"
# Lama.
# clear!
# Mowbray,
# distressed,
# Dada
# nihilist,
# Producer)
# blank.<br
# \MTV\"
# />Universal
# killer),
# Montalban,
# />'A
# Cash.
# forgivable.<br
# sequel...<br
# Planet's
# complying
# hangings,
# 36,
# \"traditional\"
# \Look,
# Punisher.
# Soldiers.
# robbing.
# lady),
# either...<br
# special;
# Zeppelin's
# Cause\",
# Nicolson
# \fake
# Stix
# order)
# Twentieth-Century
# gridiron
# boxes.<br
# become?
# Dick\"
# Hen
# imo.
# \"someone\"
# remembering,
# handcuffs,
# sort)
# Rialto
# />Quote
# Irishmen
# scorned,
# Woo)
# Demille
# \business\"
# keel.
# mid-nineties
# 'Paris'
# short),
# hand?
# Schrader,
# \baby
# face\".
# utensils
# Shanti
# effort...
# blessing,
# Himalayas.
# responses,
# 'Things
# Homeric
# structuring
# orchard
# whored
# sexualities
# carrying,
# bullock
# FINALLY,
# '90's.
# quote:<br
# lulls.
# suspense/drama
# \Manos,
# hare-brained
# lording
# Kill!
# Nakamura
# 17th-century
# docu-drama,
# best-loved
# samurai.
# bourgeoisie.
# pollutes
# downfalls,
# drawback,
# newscasters
# Bissell.
# 'Who's
# Malayalam
# cook's
# himself/herself
# rewrites.
# />Easter
# preforming
# Yes.<br
# 2000."
# woes.
# (poorly
# VanHook
# Ballard,
# causes.<br
# climax."
# containers.
# Laurie,
# 'odd'
# Manojlovic
# Mitchell.<br
# 'Life
# engenders
# proofread
# humbleness
# analogy.
# crackers,
# taxidermist.
# gums.
# pavement.
# />Forest
# regimental
# families)
# trip).
# oversight,
# (I.E.
# Elyse
# (pity
# trusted.<br
# Eleven\"
# twitch.
# bomb)
# sizzles.
# softporn
# Christa
# Madagascar
# bhai
# concept\"
# Paris\".
# />NOTE
# actor.)
# />Lacking
# Caroline.
# />Franco
# keith
# Yilmaz
# Roddy's
# forwards.
# />Cinderella
# role-playing,
# />though
# missing!
# funniest)
# sucked!!
# Tis
# fathers'
# 7+
# Hak
# Hip-hop
# book-to-film
# Grot'
# herein.<br
# self-obsessed,
# fait
# Risk\"
# kinship,
# quelled
# violation.
# afford,
# x-rated
# styling,
# Agatha.
# \Crash\"
# \"Gentleman's
# migrants
# 'taking
# Fiedler,
# BABYLON
# (walking
# in..
# slow?
# WAVE
# ideas)
# unfortunatly
# scriptwriting.
# Carnotaur
# Syfy
# 1894
# (Ghost
# late...<br
# wise)
# watchings
# 56,
# pretext.
# foolish.<br
# />Christmas
# mid-50s
# sparkles.
# malleable
# Vertigo.
# circumstances:
# associated.
# \"Keys
# KINGDOM
# (Charley
# DQ
# Marni
# \By
# (four).
# nicholson
# goddess.<br
# outlandish.
# ultimatum
# Professionals\",
# scar.
# sex-starved,
# clunker,
# laugh-inducing
# ID.
# 47,
# chequered
# (7/10)
# Paget's
# AKA:
# \"Movie\"
# 4TH
# pecker
# fondles
# mark..
# scale?
# Lava
# (mildly)
# Providence,
# ,\"
# Rope\"
# cornball,
# superlatives.
# teeth?
# schedules,
# Pamela's
# Roslin
# blessed.
# Capitan
# demonstrations.
# degeneracy
# zeal,
# grays,
# Bhoomika
# Cassavettes's
# OPENING
# unwrapping
# Shawshank,
# wonder;
# *can*
# sympathising
# Rocks,
# sorts).
# 1950s'
# flagpole
# Valery
# good?\"
# rehab,
# stumbles,
# smart-mouth
# \"Professor
# O'Dell
# Drives
# didn't),
# \"think\"
# 'Hello
# Satan.<br
# Badalamenti,
# Spartacus
# run).
# Bedouin
# Shoot,
# Owner
# infront
# \"Burn\"
# Chat
# SPOILER**
# Tunisian
# economical,
# Foch,
# \...
# clinical,
# studio-bound
# validity.
# eyelashes
# simpleton,
# gentleman\"
# argument.<br
# exhausts
# victimize
# \"any
# />Spike
# perversity.
# Barrows
# Rand.
# Spark
# 'Break
# full-size
# cal
# Parole
# Stark)
# Good's
# forward-thinking
# Caesars
# explanation?
# insignia
# simmered
# FILM!"
# Hedges,
# stage...
# her.\"
# fiend.<br
# guides,
# quarter,
# Stock.
# Meaney's
# 'regular'
# ETC
# />So.
# umbrage
# Northeastern
# shouldnt
# lyric.
# WEEKEND
# CD)
# McDevitt
# colonize
# />Sharon
# hangover.
# moan,
# movies)<br
# Family\",
# hysteric
# 1973).
# suprising
# pinpoints
# (10/10)
# nasty'
# $90,000
# newbies.
# Elements:<br
# experiential
# absurd?
# tide,
# begin:
# Friday/Saturday
# Carrière
# Washington?
# combustible
# \"Key
# Matrix)
# Doorway
# lesson\"
# apart."
# schmaltz.
# sui
# decrees
# Greystoke,
# deviant.
# empathised
# pricked
# cartoonist.
# ledge,
# lengthy.
# suspense:
# Beatriz
# Hale.
# Breasts
# strong<br
# novel\"
# posting,
# pondering,
# exhibited.
# audiences:
# spinoff
# timetable
# incarnation.
# rotoscoped,
# shiftless
# throttled
# profound.<br
# Juliana
# MIAs
# chalice
# Activision
# ideology.<br
# Buckle
# thesis,
# overload,
# commitments,
# Moores'
# Whitman.
# Filling
# excavated
# CHEESE
# \"Flowers
# Charisse,
# money),
# (police
# Whistle
# Wang)
# Election,
# omnipresent,
# PERIOD.
# cartons
# Yanks,
# Chaplin).
# (People
# counselors,
# Observing
# ineffectual.
# Ghandi.
# performed.<br
# Decision
# Lads
# \"lead\"
# big-eyed
# Audrey.
# twist:
# appeal."
# brother,who
# Bondarchuk
# Round\"
# metal's
# 7.5/10<br
# />Debbie
# integration.
# molding
# ill;
# outlines,
# letters.<br
# psychos.
# attract,
# Doren's
# machete,
# them,\"
# Stowe,
# expounded
# J.D
# mega-budget
# periodical
# time-filler
# gods.<br
# Guignol
# Gallico
# *rolls
# whetted
# Provincetown
# matron,
# relationship's
# larry
# earshot
# Bogard
# HUH?
# up.)
# Modine's
# F.W.
# Murnau.
# high-paced
# magnet.
# clench
# gravesite
# Bixby,
# approval.<br
# Chucky's
# Molloch

# %% [markdown]
# ## 预处理

# %%
from torch import nn
from gensim.models import Word2Vec
# w2v模型位置
w2v_path = "model/w2v_all.model"
class Preprocess():
  def __init__(self,sentences,sen_len,w2v_path=w2v_path):
    self.w2v_path = w2v_path
    self.sentences = sentences
    self.sen_len = sen_len
    self.idx2word = []
    self.word2idx = {}
    self.embedding_matrix = []
  
  def get_w2v_model(self):
    # 把之前保存的w2v模型加载进来
    self.embedding = Word2Vec.load(self.w2v_path)
    self.embedding_dim = self.embedding.vector_size

  def add_embedding(self,word):
    # 把word加进embedding  并赋值一个随机向量
    vector = torch.empty(1,self.embedding_dim) #return a tensor filled with uninitialed dada. shape is  (1*embedding_dim)
    #从均匀分布U(a,b)中生成值，填充参数vector，默认a=0,b=1
    torch.nn.init.uniform_(vector)
    self.word2idx[word] = len(self.word2idx)  #为word2idx字典填充后，word2idx长度会加1
    self.idx2word.append(word)
    # print("word:",word)  #str类型的单词
    # torch.cat是将两个张量（tensor）拼接在一起    按维数0拼接（竖着拼）
    self.embedding_matrix = torch.cat([self.embedding_matrix,vector],0)
    # embedding_matrix为二维矩阵（整数张量） 即embedding输入的是二维
    # print("embedding_matrix.shape",self.embedding_matrix.shape)  #二维矩阵torch.Size([121345, 250])  250为embedding_dim矩阵维度
  
  def make_embedding(self,load=True):
    print("get embedding..")
    #加载embedding模型
    if load:
      print("加载word to vec模型")
      self.get_w2v_model()
    else:
      raise NotImplementedError

    # 制作一个word2idx的字典
    # 制作一个idx2word的list
    # 制作一个word2vector的list
    for i,word in enumerate(self.embedding.wv.key_to_index ):
      print('get words #{}'.format(i+1), end='\r')
      # 例：self.word2idx['李']=1
      # self.idx2word[1]='李'
      # self.vector[1]='李'
      self.word2idx[word]=len(self.word2idx)
      self.idx2word.append(word)
      self.embedding_matrix.append(self.embedding.wv[word])
    # 将embedding_matrix转为tensor类型
    self.embedding_matrix = torch.tensor(self.embedding_matrix)
    # 将PAD和UNK加入embedding中
    self.add_embedding("<PAD>")
    self.add_embedding("<UNK>")
    print("total words: {}".format(len(self.embedding_matrix)))
    return self.embedding_matrix

  def pad_sequence(self,sentence):
    # 将每个句子变成统一的长度
    if len(sentence)>self.sen_len:
      sentence = sentence[:self.sen_len]  #截断
    else:
      pad_len = self.sen_len-len(sentence)
      for _ in range(pad_len):
        sentence.append(self.word2idx["<PAD>"])  #sentence为整形数字(序列化的)
    assert len(sentence)==self.sen_len
    return sentence

  def sentence_word2idx(self):
    # 把句子里面的字转成对应的index
    sentence_list = []
    for i,sen in enumerate(self.sentences):
      print('sentence count #{}'.format(i+1), end='\r')
      sentence_idx = []
      for word in sen:
        if(word in self.word2idx.keys()):
          sentence_idx.append(self.word2idx[word])
        else:
          sentence_idx.append(self.word2idx["<UNK>"])
      # 把每个句子长度统一
      sentence_idx = self.pad_sequence(sentence_idx)
      sentence_list.append(sentence_idx)
    return torch.LongTensor(sentence_list)

  def labels_to_tensor(self,y):
    #把标签label也转为tensor
    y = [int(label) for label in y]
    return torch.LongTensor(y)
    

print("ok")
# Out:
# ok

# %% [markdown]
# ## 数据集 类似于DataLoader

# %%
# 实现dataset所需要的'__init__', '__getitem__', '__len__'
import torch
from torch.utils import data

class TwitterDataset(data.Dataset):
  """
    Expected data shape like:(data_num, data_len)
    Data can be a list of numpy array or a list of lists
    input data shape : (data_num, seq_len, feature_dim)
    
    __len__ will return the number of data
  """
  def __init__(self,X,y):
    self.data = X
    self.label = y
  def __getitem__(self,idx):
    # 根据idx返回（data,label）
    if self.label is None:
      return self.data[idx]
    return self.data[idx],self.label[idx]
  
  def __len__(self):
    return len(self.data)

# %% [markdown]
# ## LSTM模型

# %%
import torch
from torch import nn
class LSTM_Net(nn.Module):
  def __init__(self,embedding,embedding_dim,hidden_dim,num_layers,dropout=0.5,fix_embedding=True):
    super(LSTM_Net,self).__init__()
    # 制作embedding Layer
    self.embedding = torch.nn.Embedding(embedding.size(0),embedding.size(1))
    self.embedding.weight = torch.nn.Parameter(embedding)
    # 是否将embedding fix住，如果fix_embedding为True，在训练过程中，embedding会跟着训练
    self.embedding.weight.require_grad = False if fix_embedding else True
    self.embedding_dim = embedding.size(1)
    self.hidden_dim = hidden_dim
    self.num_layers = num_layers
    self.dropout = dropout
    self.lstm = nn.LSTM(embedding_dim,hidden_dim,num_layers=num_layers,batch_first=True)
    self.classifier = nn.Sequential(nn.Dropout(dropout),nn.Linear(in_features=hidden_dim,out_features=1),nn.Sigmoid())

  def forward(self,inputs):
    inputs = self.embedding(inputs)
    x,_ = self.lstm(inputs,None)
    # x 的 dimension (batch, seq_len, hidden_size)
    # 取用LSTM最后一层的hidden state
    x = x[:,-1,:]
    x = self.classifier(x)
    return x

# %% [markdown]
# ## 训练模型

# %%
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import sys

yy_train_loss = []
yy_valid_loss = []
yy_train_acc = []
yy_valid_acc = []
xx = []
early_stopping_epoch = 30
add_num = 0
total_loss,total_acc = 0,0
best_acc = 0
pre_valid_loss = 100000
model_dir = "model"
def training(batch_size,n_epoch,lr,model_dir,train,valid,model,device):
  global add_num,total_loss,total_acc,best_acc,pre_valid_loss
  total = sum(p.numel() for p in model.parameters()) #求参数个数。对每个参数组的元素总数求和
  trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)# 求可训练参数个数
  print('\nstart training, parameter total:{}, trainable:{}\n'.format(total, trainable))
  model.train() #将model的模式设为train  这样optimizer可以更新model的参数
  criterion = nn.BCELoss()  #定义损失函数使用binary cross entropy loss
  t_batch = len(train)
  v_batch = len(valid)
  optimizer = optim.Adam(model.parameters(),lr=lr) #定义优化器
  total_loss,total_acc,best_acc = 0,0,0
  for epoch in range(n_epoch):
    xx.append(epoch)
    total_loss,total_acc = 0,0
    # train
    for i, (inputs, labels) in enumerate(train):
      # device为cuda, 将inputs转为torch.cuda.LongTensor
      inputs = inputs.to(device,dtype=torch.long)
    # device为cuda，将labels转为torch.cuda.FloatTensor，因为要计算损失criterion，所以必须是float类型
      labels = labels.to(device,dtype=torch.float)
      optimizer.zero_grad() #因为loss.backward()的gradient会累加，所以每一轮batch后梯度清零
      outputs = model(inputs) #将inputs喂给模型
      outputs = outputs.squeeze() #去掉最外面的dimension  好让outputs可以计算损失
      loss = criterion(outputs,labels) #计算损失  outputs在前  labels在后
      loss.backward() #计算loss的gradient梯度
      optimizer.step() #更新训练模型的参数
      correct = evaluation(outputs,labels) #计算此时模型的training accuracy
      total_acc += (correct/batch_size)
      total_loss += loss.item()
      print('[ Epoch{}: {}/{} ] loss:{:.3f} acc:{:.3f} '.format(
            	epoch+1, i+1, t_batch, loss.item(), correct*100/batch_size), end='\r')
    print('\nTrain | Loss:{:.5f} Acc: {:.3f}'.format(total_loss/t_batch, total_acc/t_batch*100))
    yy_train_loss.append(total_loss/t_batch)
    yy_train_acc.append(total_acc/t_batch*100)


    # 将model的模式设为eval,参数不再更新 被固定住了
    model.eval() 
    with torch.no_grad():
      total_loss,total_acc = 0,0
      for i,(inputs,labels) in enumerate(valid):
        #device为cuda，将inputs转为torch.cuda.LongTensor
        inputs = inputs.to(device,dtype=torch.long)
        # device为cuda，将labels转为torch.cuda.FloatTensor，因为要计算损失criterion，所以必须是float类型
        labels = labels.to(device,dtype=torch.float)
        outputs = model(inputs) #把inputs喂给model
        outputs = outputs.squeeze() #去掉最外面的dimension，以便计算criterion()
        loss = criterion(outputs,labels)#计算loss
        correct = evaluation(outputs,labels)#计算validation accuracy
        total_acc += (correct/batch_size)
        total_loss += loss.item()
      print("Valid | Loss:{:.5f} Acc: {:.3f} ".format(total_loss/v_batch, total_acc/v_batch*100))
      yy_valid_loss.append(total_loss/v_batch)
      yy_valid_acc.append(total_acc/v_batch*100)
                
      # early stopping,连续增长到early_stopping_epoch轮数的话，就会提前终止epoch循环,epoch = sys.maxsize
      curr_valid_loss = total_loss/v_batch
      if(curr_valid_loss>pre_valid_loss): #如果损失值持续增加  说明网络结构设计不当，训练超参数设置不当，数据集经过清洗等问题  应及时停止，不要再继续训练
        add_num+=1
        if(add_num==early_stopping_epoch): #如果loss持续增加的轮数到了early_stopping_epoch 就停止train
          epoch=sys.maxsize
      else:
        add_num=0
      pre_valid_loss = curr_valid_loss
      if total_acc/v_batch>best_acc:
        print("total_acc/v_batch:",total_acc/v_batch)
        # 如果validation的结果优于之前所有的结果  就把当前的模型保存下载 以便做预测时使用
        best_acc = total_acc/v_batch
        torch.save(model,"{}/ckpt.model".format(model_dir))
        print('saving model with acc {:.3f}'.format(total_acc/v_batch*100))
    print('-----------------------------------------------')
    model.train() #将model的模式设为train  这样optimizer可以继续更新model的参数
    # 结束for循环
  #将最好的valid的best_acc存放下来
  tt_path = "model/"+str(best_acc) +"_best_acc.txt"
  with open(tt_path,"w") as f:
    f.write(str(best_acc))
  
  
  ax1 = plt.subplot(1,2,1)
  plt.sca(ax1)
  plt.plot(xx,yy_train_loss,"r",label = "train_loss")
  plt.plot(xx,yy_valid_loss,"b",label = "valid_loss")
  plt.legend()
  ax2 = plt.subplot(1,2,2)
  plt.sca(ax2)
  plt.plot(xx,yy_train_acc,"y",label = "train_acc")
  plt.plot(xx,yy_valid_acc,"g",label = "valid_acc")
  plt.legend()
  
  print("over")
print("ok")
# Out:
# ok

# %% [markdown]
# ## 测试test

# %%
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F

def testing(batch_size,test_loader,model,device):
  # 将model的模式设为eval,参数不再更新 被固定住了
  model.eval()
  ret_output = []
  with torch.no_grad():
    for i,input in enumerate(test_loader):
      inputs = inputs.to(device,dtype=torch.long)
      outputs = model(inputs)
      outputs = outputs.squeeze()
      ret_output += outputs.float().tolist()
  return ret_output

# %% [markdown]
# ## main主函数

# %%
import os
import torch
import argparse
import numpy as np
from torch import nn
from gensim.models import word2vec
from sklearn.model_selection import train_test_split
# 同时使用多块GPU训练
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1,3"
# 判断gpu是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 导入日志模块 创建更漂亮的输出消息
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',level=logging.INFO)

# 各个data文件的路径
train_with_label = "dataset/labeledTrainData.tsv"
train_no_label = "dataset/unlabeledTrainData.tsv"
testing_data = "dataset/testData.tsv"
w2v_path = "model/w2v_all.model"

# 定义句子长度、要不要固定embedding、batch大小、epoch轮数、learning rate值、model文件路径
sen_len = 200
fix_embedding = True#训练期间固定embedding  加快训练
batch_size = 128
epoch = 200
lr = 0.001
model_dir = "model/"
print("加载数据...")
train_x,y = load_training_data(label_train_path)

# 对inputs和labels做预处理
preprocess = Preprocess(train_x,sen_len,w2v_path=w2v_path)  #实例化Preprogress类
embedding = preprocess.make_embedding(load=True)
# train_x为LongTensor类型 y也是
train_x = preprocess.sentence_word2idx()
y = preprocess.labels_to_tensor(y)

# 制作一个LSTM模型对象
model = LSTM_Net(embedding,embedding_dim=250,hidden_dim=250,num_layers=1,dropout=0.5,fix_embedding=fix_embedding)
# 同时使用多块GPU训练
if torch.cuda.device_count()>1:
  print("muti gpu")
  model = torch.nn.DataParallel(model)
model.to(device) #若cuda可用
# model = model.cuda(device)
# 把data分割为训练集和验证机
p = 0.8
split_num = int(len(train_x)*p)
X_train,X_val,y_train,y_val = train_x[:split_num],train_x[split_num:],y[:split_num], y[split_num:]

# 把data做成dataset供dataloader使用
train_dataset = TwitterDataset(X=X_train,y=y_train)
val_dataset = TwitterDataset(X=X_val,y=y_val)

# 把data转成batch of tensor
# windows多线程有报错 ，这里将num_worders改为0
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True,num_workers=0) #使用全部线程
val_loader = torch.utils.data.DataLoader(dataset=val_dataset,batch_size=batch_size,shuffle=False,num_workers=0)

# 开始训练
# training(batch_size,epoch,lr,model_dir,train_loader,val_loader,model,device)
training(batch_size, epoch, lr, model_dir, train_loader, val_loader, model, device)
# Out:
# 加载数据...
# 2022-01-17 16:53:32,111 : INFO : loading Word2Vec object from model/w2v_all.model
# 2022-01-17 16:53:32,172 : INFO : loading wv recursively from model/w2v_all.model.wv.* with mmap=None
# 2022-01-17 16:53:32,173 : INFO : loading vectors from model/w2v_all.model.wv.vectors.npy with mmap=None
# 2022-01-17 16:53:32,279 : INFO : loading syn1neg from model/w2v_all.model.syn1neg.npy with mmap=None
# get embedding..
# 加载word to vec模型
# 2022-01-17 16:53:32,405 : INFO : setting ignored attribute cum_table to None
# 2022-01-17 16:53:33,587 : INFO : Word2Vec lifecycle event {'fname': 'model/w2v_all.model', 'datetime': '2022-01-17T16:53:33.586486', 'gensim': '4.0.1', 'python': '3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'loaded'}
# word: <PAD>121343
# embedding_matrix.shape torch.Size([121344, 250])
# word: <UNK>
# embedding_matrix.shape torch.Size([121345, 250])
# total words: 121345
# sentence count #25000
# start training, parameter total:30838501, trainable:30838501
#
# [ Epoch1: 4/157 ] loss:0.720 acc:46.875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-1f9feeb84d81> in <module>
#      64 # 开始训练
#      65 # training(batch_size,epoch,lr,model_dir,train_loader,val_loader,model,device)
# ---> 66 training(batch_size, epoch, lr, model_dir, train_loader, val_loader, model, device)
#      67
#
# <ipython-input-25-aa075cde4959> in training(batch_size, n_epoch, lr, model_dir, train, valid, model, device)
#      39       labels = labels.to(device,dtype=torch.float)
#      40       optimizer.zero_grad() #因为loss.backward()的gradient会累加，所以每一轮batch后梯度清零
# ---> 41       outputs = model(inputs) #将inputs喂给模型
#      42       outputs = outputs.squeeze() #去掉最外面的dimension  好让outputs可以计算损失
#      43       loss = criterion(outputs,labels) #计算损失  outputs在前  labels在后
#
# E:\IT\code\Python\environment\Miniconda3\envs\pytorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-24-0743df9201eb> in forward(self, inputs)
#      18   def forward(self,inputs):
#      19     inputs = self.embedding(inputs)
# ---> 20     x,_ = self.lstm(inputs,None)
#      21     # x 的 dimension (batch, seq_len, hidden_size)
#      22     # 取用LSTM最后一层的hidden state
#
# E:\IT\code\Python\environment\Miniconda3\envs\pytorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# E:\IT\code\Python\environment\Miniconda3\envs\pytorch\lib\site-packages\torch\nn\modules\rnn.py in forward(self, input, hx)
#     678         if batch_sizes is None:
#     679             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 680                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     681         else:
#     682             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
import torch
import os
print(torch.cuda.is_available())
# USE muti GPU
torch.cuda.set_device(0)
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'
# 判断gpu是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-495298c449ae> in <module>
#       3 print(torch.cuda.is_available())
#       4 # USE muti GPU
# ----> 5 torch.cuda.set_device(0)
#       6 os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'
#       7 # 判断gpu是否可用
#
# E:\IT\code\Python\environment\Miniconda3\envs\pytorch\lib\site-packages\torch\cuda\__init__.py in set_device(device)
#     262     device = _get_device_index(device)
#     263     if device >= 0:
# --> 264         torch._C._cuda_setDevice(device)
#     265
#     266
#
# AttributeError: module 'torch._C' has no attribute '_cuda_setDevice'

# %%
print("1")
print(test_x)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
